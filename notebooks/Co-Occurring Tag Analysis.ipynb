# %% [markdown]
# # Co-Occurring Tag Analysis
#
# Analysing how tags co-occur across various Parliamentary publications. The idea behind this is to see whether there are naturally occurring groupings of topic tags by virtue of their co-occurence when used to tag different classes of Parlimanetary publication.

# %%
#Data files
# !ls data/dataexport
# Out:
# edms        proceedings terms

# %% [markdown]
# ## Utils

# %% [markdown]
# Import a library that lets us work with the data files:

# %%
#Data is provided as Turtle/ttl files - rdflib handles those

#!pip3 install rdflib
from rdflib import Graph

# %% [markdown]
# Simple utility to load all the `.ttl` files in a particular directory into a graph:

# %%
import os
def ttl_graphbuilder(path,g=None,debug=False):
    if g is None:
        g=Graph()
    for ttl in [f for f in os.listdir(path) if f.endswith('.ttl')]:
        if debug: print(ttl)
        g.parse('{}/{}'.format(path,ttl), format='turtle')
    return g

# %% [markdown]
# Tools for running queries over a graph and either printing the result or putting it into a `pandas` dataframe:

# %%
def rdfQuery(graph,q):
    ans=graph.query(q)
    for row in ans:
        for el in row:
            print(el,end=" ")
        print()

#ish via https://github.com/schemaorg/schemaorg/blob/sdo-callisto/scripts/dashboard.ipynb
import pandas as pd
def sparql2df(graph,q, cast_to_numeric=True):
    a=graph.query(q)
    c = []
    for b in a.bindings:
        rowvals=[]
        for k in a.vars:
            rowvals.append(b[k])
        c.append(rowvals)

    df = pd.DataFrame(c)
    df.columns = [str(v) for v in a.vars]
    if cast_to_numeric:
        df = df.apply(lambda x: pd.to_numeric(x, errors='ignore'))

    return df

# %% [markdown]
# Tools to support the export and display of graphs - `netowrkx` package is handy in this respect, eg exporting to GEXF format for use with Gephi.

# %%
import networkx as nx

# %% [markdown]
# ## Exploring the Data - Terms

# %%
path='data/dataexport/terms'
termgraph=ttl_graphbuilder(path)

# %%
#What's in the graph generally?
q='''
SELECT DISTINCT ?x ?y ?z {
    # ?x ?y ?z.
} LIMIT 10
'''
rdfQuery(termgraph,q)
# Out:
# http://data.parliament.uk/terms/93225 http://www.w3.org/2004/02/skos/core#narrower http://data.parliament.uk/terms/90383
# http://data.parliament.uk/terms/414110 http://www.w3.org/2004/02/skos/core#notation
# http://data.parliament.uk/terms/408942 http://www.w3.org/2004/02/skos/core#related http://data.parliament.uk/terms/60315
# http://data.parliament.uk/terms/357565 http://www.w3.org/2004/02/skos/core#narrower http://data.parliament.uk/terms/349840
# http://data.parliament.uk/terms/60278 http://www.w3.org/2004/02/skos/core#exactMatch http://data.parliament.uk/terms/97318
# http://data.parliament.uk/terms/37000 http://www.w3.org/2004/02/skos/core#notation ORG
# http://data.parliament.uk/terms/1326 http://www.w3.org/2004/02/skos/core#broader http://data.parliament.uk/terms/1
# http://data.parliament.uk/terms/83361 http://www.w3.org/2004/02/skos/core#prefLabel Standing Veterinary Committee
# http://data.parliament.uk/terms/300910 http://www.w3.org/2004/02/skos/core#exactMatch http://data.parliament.uk/terms/313904
# http://data.parliament.uk/terms/431592 http://www.w3.org/2004/02/skos/core#broader http://data.parliament.uk/terms/1

# %%
#What does a term have associated with it more specicfically?
q='''
SELECT DISTINCT ?y ?z {
    <http://data.parliament.uk/terms/95551> ?y ?z.
} LIMIT 10
'''
rdfQuery(termgraph,q)
# Out:
# http://www.w3.org/2004/02/skos/core#narrower http://data.parliament.uk/terms/95502
# http://www.w3.org/2004/02/skos/core#narrower http://data.parliament.uk/terms/95494
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2004/02/skos/core#Concept
# http://www.w3.org/2004/02/skos/core#notation TPG
# http://www.w3.org/2004/02/skos/core#narrower http://data.parliament.uk/terms/95550
# http://www.w3.org/2004/02/skos/core#broader http://data.parliament.uk/terms/95548
# http://www.w3.org/2004/02/skos/core#prefLabel Defence policy
# http://www.w3.org/2004/02/skos/core#narrower http://data.parliament.uk/terms/95586

# %% [markdown]
# Looks like the label is what we want:

# %%
q='''
SELECT DISTINCT ?z ?topic {
    # ?z <http://www.w3.org/2004/02/skos/core#prefLabel> ?topic.
} LIMIT 10
'''
sparql2df(termgraph,q)
# Out:
#                                        z  \
# 0  http://data.parliament.uk/terms/90385
# 1   http://data.parliament.uk/terms/4491
# 2  http://data.parliament.uk/terms/28888
# 3  http://data.parliament.uk/terms/24830
# 4  http://data.parliament.uk/terms/84469
# 5  http://data.parliament.uk/terms/36872
# 6  http://data.parliament.uk/terms/65884
# 7  http://data.parliament.uk/terms/67412
# 8  http://data.parliament.uk/terms/83361
# 9  http://data.parliament.uk/terms/50788
#
#                                         topic
# 0                     Broadcasting programmes
# 1                      British Airports Group
# 2        Derbyshire Royal Infirmary NHS Trust
# 3      Citizens Charter Complaints Task Force
# 4                   UK Energy Research Centre
# 5  Graduate School of Business Administration
# 6                               Railway Group
# 7                       Safety-Net Foundation
# 8               Standing Veterinary Committee
# 9                     Probation and aftercare

# %% [markdown]
# ## Exploring the Data - EDMS

# %%
path='data/dataexport/edms'
g=ttl_graphbuilder(path)

# %%
#See what's there generally...
q='''
SELECT DISTINCT ?x ?y ?z {
    # ?x ?y ?z.
} LIMIT 10
'''
rdfQuery(g,q)
# Out:
# http://data.parliament.uk/edms/50212 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://data.parliament.uk/schema/parl#EarlyDayMotion
# http://data.parliament.uk/edms/50457 http://data.parliament.uk/schema/parl#motionText That this House notes the announcement of 300 redundancies at the Nestlé manufacturing factories in York, Fawdon, Halifax and Girvan and that production of the Blue Riband bar will be transferred to Poland; acknowledges in the first three months of 2017 Nestlé achieved £21 billion in sales, a 0.4 per cent increase over the same period in 2016; further notes 156 of these job losses will be in York, a city that in the last six months has seen 2,000 job losses announced and has become the most inequitable city outside of the South East, and a further 110 jobs from Fawdon, Newcastle; recognises the losses come within a month of triggering Article 50, and as negotiations with the EU on the UK leaving the EU and the UK's future with the EU are commencing; further recognises the cost of importing products, including sugar, cocoa and production machinery, has risen due to the weakness of the pound and the uncertainty over the UK's future relationship with the single market and customs union; and calls on the Government to intervene and work with hon. Members, trades unions GMB and Unite and the company to avert these job losses now and prevent further job losses across Nestlé.
# http://data.parliament.uk/edms/49408 http://data.parliament.uk/schema/parl#topic http://data.parliament.uk/terms/95650
# http://data.parliament.uk/edms/49467 http://data.parliament.uk/schema/parl#topic http://data.parliament.uk/terms/95676
# http://data.parliament.uk/edms/49667 http://data.parliament.uk/schema/parl#topic http://data.parliament.uk/terms/95758
# http://data.parliament.uk/edms/50446 http://purl.org/dc/terms/date 2017-04-24T23:00:00+00:00
# http://data.parliament.uk/edms/49677 http://purl.org/dc/terms/date 2016-09-06T23:00:00+00:00
# http://data.parliament.uk/edms/50210 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://data.parliament.uk/schema/parl#EarlyDayMotion
# http://data.parliament.uk/edms/49500 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://data.parliament.uk/schema/parl#EarlyDayMotion
# http://data.parliament.uk/edms/49973 http://data.parliament.uk/schema/parl#topic http://data.parliament.uk/terms/95518

# %%
#Explore a specific EDM
q='''
SELECT DISTINCT ?y ?z {
    <http://data.parliament.uk/edms/50457> ?y ?z.
}
'''
rdfQuery(g,q)
# Out:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://data.parliament.uk/schema/parl#EarlyDayMotion
# http://data.parliament.uk/schema/parl#motionText That this House notes the announcement of 300 redundancies at the Nestlé manufacturing factories in York, Fawdon, Halifax and Girvan and that production of the Blue Riband bar will be transferred to Poland; acknowledges in the first three months of 2017 Nestlé achieved £21 billion in sales, a 0.4 per cent increase over the same period in 2016; further notes 156 of these job losses will be in York, a city that in the last six months has seen 2,000 job losses announced and has become the most inequitable city outside of the South East, and a further 110 jobs from Fawdon, Newcastle; recognises the losses come within a month of triggering Article 50, and as negotiations with the EU on the UK leaving the EU and the UK's future with the EU are commencing; further recognises the cost of importing products, including sugar, cocoa and production machinery, has risen due to the weakness of the pound and the uncertainty over the UK's future relationship with the single market and customs union; and calls on the Government to intervene and work with hon. Members, trades unions GMB and Unite and the company to avert these job losses now and prevent further job losses across Nestlé.
# http://purl.org/dc/terms/date 2017-04-25T23:00:00+00:00
# http://data.parliament.uk/schema/parl#topic http://data.parliament.uk/terms/95591
# http://data.parliament.uk/schema/parl#topic http://data.parliament.uk/terms/95530

# %% [markdown]
# Let's merge the EDM graph data with the terms data.

# %%
path='data/dataexport/edms'
g=ttl_graphbuilder(path,termgraph)

# %% [markdown]
# Now we can look at the term labels associated with a particular EDM.

# %%
q='''
SELECT DISTINCT ?t ?z {
    <http://data.parliament.uk/edms/50114> <http://data.parliament.uk/schema/parl#topic> ?z.
    # ?z <http://www.w3.org/2004/02/skos/core#prefLabel> ?t.
} LIMIT 10
'''
rdfQuery(g,q)
# Out:
# Arms control http://data.parliament.uk/terms/95494
# Defence policy http://data.parliament.uk/terms/95551
# International politics and government http://data.parliament.uk/terms/95650
# North America http://data.parliament.uk/terms/95690

# %% [markdown]
# We can also create a table that links topic labels with EDMs.

# %%
q='''
SELECT DISTINCT ?edms ?topic {
    # ?edms <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://data.parliament.uk/schema/parl#EarlyDayMotion>.
    # ?edms <http://data.parliament.uk/schema/parl#topic> ?z.
    # ?z <http://www.w3.org/2004/02/skos/core#prefLabel> ?topic.
}
'''
g_df=sparql2df(g,q)
g_df.head()
# Out:
#                                    edms                     topic
# 0  http://data.parliament.uk/edms/50424  Sports and Olympic Games
# 1  http://data.parliament.uk/edms/50424     Children and families
# 2  http://data.parliament.uk/edms/50129           Adult education
# 3  http://data.parliament.uk/edms/49551  Sports and Olympic Games
# 4  http://data.parliament.uk/edms/50276  Sports and Olympic Games

# %% [markdown]
# From this table, we can a generate a bipartite `networkx` graph that links topic labels with EDMs.

# %%
nxg=nx.from_pandas_dataframe(g_df, 'edms', 'topic')
#nx.write_gexf(nxg,'edms.gexf')

# %% [markdown]
# We can then project this bipartite graph onto just the topic label nodes - edges will now connect nodes that are linked through one or more common EDMs.

# %%
from networkx.algorithms import bipartite
#We can find the sets of names/tags associated with the disjoint sets in the graph
edms,topic=bipartite.sets(nxg)

#Collapse the bipartite graph to a graph of topic lables connected via a common EDM
topicgraph= bipartite.projected_graph(nxg, topic)
nx.write_gexf(topicgraph,'edms_topics.gexf')

# %% [markdown]
# We can also generate a weighted graph, where edges are weighted relative to how many times topics are linked through different EDMs.

# %%
topicgraph_weighted= bipartite.weighted_projected_graph(nxg, topic)
nx.write_gexf(topicgraph_weighted,'edms_topics_weighted.gexf')

# %% [markdown]
# ## Exploring the Data - proceedings

# %%
path='data/dataexport/proceedings'
p=ttl_graphbuilder(path,debug=True)
# Out:
# 0006D323-D0B5-4E22-A26E-75ABB621F58E.ttl
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-111-e3cc91dfc0eb>", line 2, in <module>
#     p=ttl_graphbuilder(path,debug=True)
#
#   File "<ipython-input-110-9b9078d48c95>", line 7, in ttl_graphbuilder
#     g.parse('{}/{}'.format(path,ttl), format='turtle')
#
#   File "/usr/local/lib/python3.6/site-packages/rdflib/graph.py", line 1043, in parse
#     parser.parse(source, self, **args)
#
#   File "/usr/local/lib/python3.6/site-packages/rdflib/plugins/parsers/notation3.py", line 1870, in parse
#     p.loadStream(source.getByteStream())
#
#   File "/usr/local/lib/python3.6/site-packages/rdflib/plugins/parsers/notation3.py", line 434, in loadStream
#     return self.loadBuf(stream.read())    # Not ideal
#
#   File "/usr/local/lib/python3.6/site-packages/rdflib/plugins/parsers/notation3.py", line 440, in loadBuf
#     self.feed(buf)
#
#   File "/usr/local/lib/python3.6/site-packages/rdflib/plugins/parsers/notation3.py", line 466, in feed
#     i = self.directiveOrStatement(s, j)
#
#   File "/usr/local/lib/python3.6/site-packages/rdflib/plugins/parsers/notation3.py", line 487, in directiveOrStatement
#     j = self.statement(argstr, i)
#
#   File "/usr/local/lib/python3.6/site-packages/rdflib/plugins/parsers/notation3.py", line 725, in statement
#     j = self.property_list(argstr, i, r[0])
#
#   File "/usr/local/lib/python3.6/site-packages/rdflib/plugins/parsers/notation3.py", line 1086, in property_list
#     i = self.objectList(argstr, j, objs)
#
#   File "/usr/local/lib/python3.6/site-packages/rdflib/plugins/parsers/notation3.py", line 1134, in objectList
#     i = self.object(argstr, i, res)
#
#   File "/usr/local/lib/python3.6/site-packages/rdflib/plugins/parsers/notation3.py", line 1406, in object
#     j = self.subject(argstr, i, res)
#
#   File "/usr/local/lib/python3.6/site-packages/rdflib/plugins/parsers/notation3.py", line 733, in subject
#     return self.item(argstr, i, res)
#
#   File "/usr/local/lib/python3.6/site-packages/rdflib/plugins/parsers/notation3.py", line 829, in item
#     return self.path(argstr, i, res)
#
#   File "/usr/local/lib/python3.6/site-packages/rdflib/plugins/parsers/notation3.py", line 837, in path
#     j = self.nodeOrLiteral(argstr, i, res)
#
#   File "/usr/local/lib/python3.6/site-packages/rdflib/plugins/parsers/notation3.py", line 1472, in nodeOrLiteral
#     j, s = self.strconst(argstr, i, delim)
#
#   File "/usr/local/lib/python3.6/site-packages/rdflib/plugins/parsers/notation3.py", line 1565, in strconst
#     "newline found in string literal")
#
#   File "<string>", line unknown
# BadSyntax

# %%
# !ls {path}
# Out:
# 0006D323-D0B5-4E22-A26E-75ABB621F58E.ttl
# 00133F82-F04E-4F1E-AE6C-CC5B6720E072.ttl
# 00329467-EFFF-4C18-B4C7-D6511C43C146.ttl
# 00DA951D-1DF2-4DAF-ABDE-CBFFD2958838.ttl
# 01A4E161-A86D-4A22-BAB2-AEC9E07A19C6.ttl
# 02239CBB-E462-439D-853A-98D0D8156C60.ttl
# 024D61E2-09CB-4055-8E88-3F842A27FBF1.ttl
# 02C8BCC1-6BF4-4B49-8D8E-D3B6589DB26B.ttl
# 02DB9D81-010A-436E-8E00-7E3F5CAC95E1.ttl
# 02ED21B0-A2A6-4161-919C-3B143EE887D0.ttl
# 02F5D2BC-B031-40E2-B918-56C126FDCED1.ttl
# 03556065-507A-4B4E-A824-66DD1E96E105.ttl
# 0372A8D2-E0DB-4FF8-889D-4981676A943C.ttl
# 0382E657-48C5-457A-81E3-2CF5C522FCE9.ttl
# 03BFC240-9C9F-43E1-A04F-DA604D52A79E.ttl
# 03E1F7D7-CD11-4E54-829B-4FA67DE210F3.ttl
# 0401820A-2896-4F56-BB87-759B20CF834D.ttl
# 0439FDFB-2EB6-4014-9789-7826216C2410.ttl
# 049A4CE6-CC57-411C-9507-1F86D6EB1024.ttl
# 04B908B8-D29F-4CA2-A760-F346A325A817.ttl
# 04FF79AD-B0C2-44D1-8A1C-EA7C770D155B.ttl
# 0535AD72-6401-41BD-911B-706C3BDD17C4.ttl
# 059C4CD3-B876-41A4-8ACD-046109416476.ttl
# 05EBDFD7-C789-41C9-8F3B-61F9E5B806E0.ttl
# 064415AF-EC2A-41D0-8A13-0ABA5318CA7A.ttl
# 07780C78-5204-47EB-B339-9CCEE2129077.ttl
# 077D30E7-4A38-4B6D-9708-A2BCE971FC42.ttl
# 078837E6-3DDF-4FC9-AB84-08192917B9F0.ttl
# 07B89A35-3D1B-4D4E-8F28-E22DC9DFC2C9.ttl
# 07F9C2A8-031D-4A59-9C72-981885B7D6E7.ttl
# 0936937D-8DD1-4B79-9DF8-53417492491B.ttl
# 093A9D10-68F0-478F-A947-946B9A11823B.ttl
# 09550611-8605-41AB-89DA-08C4F82A8E11.ttl
# 096E2854-4771-4023-AC89-496BBFF65B5D.ttl
# 09C0E2EA-B8E2-4443-BDD1-EC56C625E564.ttl
# 0A065836-8978-4F9E-94D0-479421331F8A.ttl
# 0A1EEF00-31B0-47C9-9554-348686C7563D.ttl
# 0A46EDB4-4A0F-4CD2-A72B-99E76D14528B.ttl
# 0A4AFAB7-A39A-44FB-BD15-14B29FCAFFE6.ttl
# 0A542677-3FE1-4FF3-8035-17F6E5A964E6.ttl
# 0A97A886-8621-4C9F-B053-584E54E2D69C.ttl
# 0ABD2BAF-E90E-47C4-BA15-0C8A98059612.ttl
# 0AD1729E-E7CC-489B-9048-DDC0C20E2777.ttl
# 0B114054-9126-4942-918A-D0733028E74B.ttl
# 0B257E86-7A03-4B2E-8EE5-4304614533DF.ttl
# 0B68CDFA-B18D-45C9-A637-DFC3EFB813AF.ttl
# 0B815504-6EE6-45C9-9854-85FD2A390A76.ttl
# 0B8F8427-907F-4E98-8FC8-8179CFAF1C5F.ttl
# 0BAF2BEB-510F-41B9-94B7-81D7C9715F13.ttl
# 0C3F1385-D6DB-4DAD-B492-E99DE0D2064C.ttl
# 0CDBF1EA-7122-40EA-82C5-8922F2C5D390.ttl
# 0CDEBC9C-990D-4846-ACC4-420AD4F3E51A.ttl
# 0D2198F8-D4EA-4965-B16E-30EEB6ADEBAF.ttl
# 0D291850-E72E-4DA8-9311-8FBD5C8C8CEC.ttl
# 0D85E1B5-5C7E-49ED-83BE-8865D5BDD380.ttl
# 0D898C87-DE94-4B1E-B3B9-5BB2EBBF1DAE.ttl
# 0DB335B5-5CF5-4200-B4F5-650D6DD1FE1F.ttl
# 0DF20776-17E4-474D-8A68-F84FE70F15EA.ttl
# 0E7173BA-C93C-4B53-9428-A441AEA0990A.ttl
# 0EB2E459-5184-41F9-97CC-16D0A00B4480.ttl
# 0EDD2EA5-5E6C-419B-A11E-5ADC9A4A4B24.ttl
# 0F883FD3-211D-40C7-ACA2-5A67860E87B9.ttl
# 0F8CB188-8A94-43CC-B0DE-D36BE6354054.ttl
# 0FD6FF8B-9D32-462B-AED6-1878BCF695B1.ttl
# 10211F7A-CA92-4F78-8250-9430D2549E77.ttl
# 1052E233-E194-4689-911C-04E0776E33A3.ttl
# 10A00BB1-6FD3-473C-8D43-F81FC33071FF.ttl
# 10F228AC-C589-4A6E-861A-68C361D10A90.ttl
# 119D03B2-28E7-4537-B3F7-30328EF22157.ttl
# 1288CF9A-90F0-4D4C-B5AB-16F979C5EFDB.ttl
# 12BB6384-D1C9-4F61-81DD-3BD6B2EF74C9.ttl
# 12C43BD1-D8F4-4707-AD2C-6E0FE7125BF2.ttl
# 12F9207A-7325-4DF7-B11B-25139FF93C00.ttl
# 141B504D-E326-48D8-A88F-6673BB2DFE59.ttl
# 1428933A-ED5D-400B-8E42-AD6FF0756D0E.ttl
# 146F53E0-1943-4496-9F5B-EEEBE35497AB.ttl
# 14859A47-9C6D-44A1-9226-96281E3FDD19.ttl
# 14EB9E6D-AAEA-49BE-9D20-CFDC3F7617CF.ttl
# 151E8445-FBED-479B-B2EA-84EBEE8FE00C.ttl
# 15467C5B-6742-4024-80A1-8561D92ACA36.ttl
# 1571E7D9-9219-4A23-BB9D-373EE31CA2D8.ttl
# 1596BED7-ACA2-4D96-9430-7A9F63D8796D.ttl
# 15E0BEF6-5608-4A0A-8042-9C599F90B08B.ttl
# 15FCF79F-678F-4F22-8F1F-B66263AA8ABF.ttl
# 160E7239-27EB-4074-AA28-8164AD76ECDC.ttl
# 16276464-6091-431A-ACA4-BF25C6DF4B27.ttl
# 1630F651-AD7D-494B-BC08-5C47AF675D24.ttl
# 16829ED1-5EAD-460E-8E3E-A521B983F048.ttl
# 16CA2DF0-4123-45EB-B89F-1954CF655C18.ttl
# 172163FF-52C3-488E-9880-63FD42229640.ttl
# 1914A6D2-0F31-4147-92DC-A0CC380A114D.ttl
# 191D7D37-3AE6-484F-A81C-8BA0CAB3D7D7.ttl
# 193E9531-F5B8-4911-A808-3D62D62D876F.ttl
# 19585142-D09B-4D8F-839A-B0CB215AF054.ttl
# 198FD9FC-CB33-48CA-A0B6-03A220AD70C7.ttl
# 1A51449B-5334-42DC-9F60-60C2AD85E0F7.ttl
# 1ABAD3E2-95E3-48E6-9248-145C2613D408.ttl
# 1ACC3953-D63D-4886-B729-636360B2C515.ttl
# 1AD88318-4F1B-4DF9-A31B-38F36956734F.ttl
# 1B49E760-5CB1-4106-BFD8-25B173658062.ttl
# 1BE3B464-62EE-49FE-A83E-DF6B27ABA98C.ttl
# 1C8F8D6D-37B6-4327-88C8-27E489E18A7E.ttl
# 1CBE4575-3381-4968-BE69-74C351DAB1B3.ttl
# 1CD84796-9882-4CC6-A60E-380EB84A3658.ttl
# 1D1FB7CB-577F-495B-BF26-926C86848CFD.ttl
# 1D79182E-1388-4D56-8248-EAEA52E13C6A.ttl
# 1DB5B4F5-AAD3-446B-BDC7-95B7D8691229.ttl
# 1E0C8466-D53C-4387-BCEE-9B7C6984505E.ttl
# 1E2248BD-3BE4-401C-AC32-3BA6E44B901C.ttl
# 1E5BA9BE-2A26-4678-94A7-3E6E449AE358.ttl
# 1E64F8D8-0497-422E-90CA-6D3187835A5D.ttl
# 1E6FEC7E-6FF5-4E3D-8788-AF1CB7DE868C.ttl
# 1F15888F-E77B-4F81-A283-A7113B98B11C.ttl
# 1F6402C5-3233-4CCE-B5D6-3A2768290E79.ttl
# 20328359-D700-4C4C-B99F-0A51469BE5ED.ttl
# 20803E1A-F933-430B-9628-6F36FF9DA059.ttl
# 210C5520-9713-4C11-8230-6A1A03D4E583.ttl
# 214C3106-9262-465A-9C38-0D70F0845193.ttl
# 21DE62E6-B9F3-4609-9A10-41C232F12D7A.ttl
# 21F80C19-91A6-4417-9A2A-F7DB336E1229.ttl
# 22147733-A6EE-4978-9AD6-FF4F9C66F700.ttl
# 2225EED0-46B8-42B4-B367-3664EBA9825C.ttl
# 23005C9F-ECC5-4199-AFB0-0FE73C09E6AC.ttl
# 2305BCD6-5562-4959-B87C-1E50D2B6F9C4.ttl
# 23251E3F-515F-4A25-9370-ED348D915054.ttl
# 239B0CE5-9CDC-4B44-8F40-CFD3D6E32C47.ttl
# 23E3555E-5073-45E0-879F-DD25B2D6C531.ttl
# 2462C60D-22A3-40C9-AFE4-0E80D9388E76.ttl
# 24A03D58-0C29-44DC-BBD3-C80D337E111D.ttl
# 24AC23A1-0A86-41B0-9723-871AF14EEFDE.ttl
# 250E82BE-3A4D-4A4C-AC85-BC6C06E9808D.ttl
# 25247674-9062-4A06-8928-F7A5AD03D942.ttl
# 252A4BB0-A5C5-4078-84C0-49E5AD4C882F.ttl
# 25E455A4-F4E9-45B2-B7A3-30D8633A2DE6.ttl
# 265A8708-FB11-4A7A-8B6A-9FD936374862.ttl
# 268F1696-D8F1-424E-B337-53A91F816A94.ttl
# 26A3FCF2-0C19-44AE-93CC-6FB2CD42C895.ttl
# 26E9AAC3-3752-49A2-AB0C-DAFEDA03DFD6.ttl
# 2717D0B7-F6F3-4E21-B8E2-90D8E59BBBFE.ttl
# 272C8554-42C7-4105-8F50-CA329D60AA2D.ttl
# 273CFFDA-949D-4D0B-978A-366E054E20A2.ttl
# 277A715B-B171-4CF2-B133-6C0AD38A5F4D.ttl
# 2822A131-0808-42C7-89D8-C3DC0079FEF2.ttl
# 2857E036-2569-4A6C-A2DC-EDC29BB4DA0E.ttl
# 287F228E-BF08-4A82-815B-AA5449A17E75.ttl
# 2895D826-644D-493D-B49A-59A6808F326E.ttl
# 28AAEB45-7AFB-4780-8511-E8972B27529B.ttl
# 29508677-4AB2-438F-BF80-ED579DC90831.ttl
# 29565AF1-378D-4252-9580-6E26DA664C7D.ttl
# 2975226F-289A-4961-9745-B8018EB62BA9.ttl
# 29A78F86-DEEF-49A3-AB72-9FAFC59F9E50.ttl
# 2A0FB51C-C72E-4841-9B99-027561E7ACC3.ttl
# 2A6C5E35-3188-426D-8FBD-763C1E937110.ttl
# 2A7B00F2-FFE6-44F7-93DE-231F3E35EC73.ttl
# 2AC44FFD-E913-44F0-BB2D-3F7D3E0EC9BE.ttl
# 2B01BB5B-5DE0-4107-B4D3-5E7EB59087D9.ttl
# 2B15D871-FDCE-4538-A1C3-D16ADC382242.ttl
# 2B5D5EFD-1E33-4C67-9E83-DD6EF69DCCE2.ttl
# 2B81F514-79C7-4846-A0A3-A043881E5AC9.ttl
# 2BC2B946-E2B1-46D9-8DD5-3F703F43A721.ttl
# 2BFB1CD5-4DD2-431F-80C8-8D7464372334.ttl
# 2C05AC8F-BC45-47A6-9EB0-B52FE5EEB958.ttl
# 2C3FE1FD-2077-4730-AAB8-B23DC1010AD4.ttl
# 2C5A1C41-458A-4F37-AEE4-FF99BD2A4B03.ttl
# 2CE1A72A-45EC-4975-AED8-4FF7E77A1E77.ttl
# 2CE889BC-2110-4660-9F28-DBBEFB929FAF.ttl
# 2D2D2638-36D7-4FDA-96E2-0BD662738A85.ttl
# 2D3CE08D-AE3F-46A0-A934-53797EC37BD4.ttl
# 2D61F36E-B1B9-4893-976F-56DBFC2B19C0.ttl
# 2D66F2FD-D7F7-447B-9FA5-6E07E9D2AA68.ttl
# 2DC3C8CC-04DF-4420-82B5-9CDAEEE8EEA3.ttl
# 2DD01867-21A6-4B43-B197-71F8B1762BB3.ttl
# 2E4798CD-3309-41FF-A777-553443D44C42.ttl
# 2E848883-6485-4F85-978A-21AD365EB307.ttl
# 2EA46B28-7B3A-4787-ACF3-A487C71AB3F1.ttl
# 2F2CEEFE-34C0-4222-8E83-AE147190D2A2.ttl
# 2F7B4E9E-3683-4E26-A2BE-18540DF14EE5.ttl
# 2F88F989-2827-423D-8F86-265DEF36B878.ttl
# 2F90F535-B700-4C03-87ED-017F292535E3.ttl
# 2FC9B7EF-082D-45FD-9EF7-6134B853A862.ttl
# 2FEF1664-7924-4826-AC73-A21F116D09B2.ttl
# 30125368-42FE-4059-8546-2EEEFA9A0B42.ttl
# 308B61CD-DD9B-4779-875F-82C9A39443DD.ttl
# 3096E45E-0CCB-48A2-BF52-ECFAED98DD88.ttl
# 30C9D403-409A-4ACC-B8DB-2492B76AAEC9.ttl
# 30E26FD9-F233-4C82-8E03-5BAF2E6A75C3.ttl
# 30E2C33F-1535-4AE7-9B47-FC4D1459C3CD.ttl
# 311E9D17-1E00-4596-9425-14B8DBC4698E.ttl
# 31304CE3-07D5-4EA1-A7C4-365A27E398A9.ttl
# 3143B7AF-4492-4C02-9088-BCC9701CA3D3.ttl
# 317303AC-96CF-4835-AEBE-5066B9C47B26.ttl
# 31BA0069-C636-4B8A-88FE-2F5BA6B7BFEB.ttl
# 31C8E5B1-1259-42F3-B554-D2AEE33965F0.ttl
# 31F76AF3-934D-44AD-B086-F68ABFDAFB7D.ttl
# 323FB1FF-C016-4943-B923-B55286F566F4.ttl
# 32694CC2-285A-43FC-968F-E37C05135F55.ttl
# 32E9A069-8715-4BAF-8C43-A265851D837A.ttl
# 333A95C9-B807-46A7-8E68-51BA0CBE3BE8.ttl
# 336113E7-D5A3-4858-898E-00360E9F71AE.ttl
# 3411A346-E841-4574-87D4-C6FF0E72F49A.ttl
# 341FAEB5-149B-42E9-A51E-09245DB80914.ttl
# 3423580A-B75D-4409-9230-A512F1064E36.ttl
# 342CBEB4-B96B-4B12-9DC0-2DF87842683F.ttl
# 34332A7E-5AEE-4B88-BBC6-04FBA5A1E02B.ttl
# 3448B5B1-A615-4872-8165-784B8D2CB0F3.ttl
# 347B64FA-20CB-41B6-A2F4-45D15688E845.ttl
# 34DF13F2-9770-4C15-B232-5C9F9A4EFD54.ttl
# 352EAC99-5E49-4607-BC7F-5C725F317C24.ttl
# 35B5D2F4-02AC-45E7-9189-E3D17AFCC645.ttl
# 35D2512D-1FD8-4468-8494-EE4E84A8FBBD.ttl
# 36394BF8-367E-446A-81AF-24B9DFEB5A79.ttl
# 370C341B-F497-40A4-BBBC-E2851BE7FB52.ttl
# 37545CAD-3DAB-4E15-A192-947D33A74731.ttl
# 37804EED-608F-4486-8D44-40E959D75219.ttl
# 37C416B5-586C-4974-885D-6B728ADA95F9.ttl
# 37C8B112-5F21-4BF6-91C5-868BA58F1F76.ttl
# 380FA1CB-DA86-43B4-B5DA-A21FBBD40AF0.ttl
# 38C74A68-CDC6-46E9-8087-A1E58DA8DE3E.ttl
# 38E7625D-5DFE-481F-B8CB-F40318578AAC.ttl
# 38F7468E-ACC8-47D3-B787-052D55A8BEAE.ttl
# 391BC91D-1119-4306-811E-9C3B15853B7B.ttl
# 39CD7059-7F61-457D-8877-95E9DAD601A8.ttl
# 39E6BC04-673D-4E22-8238-1BE7BAB0D227.ttl
# 3A695396-2F45-463E-A95E-B7B7DC607181.ttl
# 3AAD989F-5DB5-4707-8ADC-FD35F6D83A4E.ttl
# 3AF1D132-4AF7-421A-86C3-5D5CAB2231F1.ttl
# 3B498AD4-BDEC-4923-B87C-196372AD4A6F.ttl
# 3B8CC8DC-BF7C-4425-BB80-C070B238B9D6.ttl
# 3BC39592-A58F-4E9A-A518-320CCBD4ED8D.ttl
# 3BD542AC-4297-4AF2-BC7D-7F79F0CF3181.ttl
# 3BEA9E7B-2883-4755-A8BB-D14E3051C61A.ttl
# 3C07AA05-64F3-4DC1-B50F-AECC2309AEE1.ttl
# 3C32B2FE-3B5E-484C-99DB-DFED09027FE4.ttl
# 3C5EE412-9319-4017-BE58-E445FDB24DB2.ttl
# 3CD2CDA5-66E5-49E0-9C1A-428314A3716C.ttl
# 3D7DCC52-E70E-488D-85AF-4E6646F4A1E0.ttl
# 3D9D7313-EB61-48A4-AF17-590423C12B7E.ttl
# 3DAC55EA-0CD2-4209-A8E9-952F76BD8551.ttl
# 3DBD828B-0D06-4EB1-9F7C-89A3086B2C33.ttl
# 3DE97549-94E2-4E75-BF6B-E223590270CE.ttl
# 3E0AA8EB-8453-41A5-89FA-11E661F1F2D3.ttl
# 3E1263C8-72A0-4DF1-9B99-DB3CE5FD3101.ttl
# 3E12B9D9-E282-4B17-AC23-5E71D8F56323.ttl
# 3E4C91DC-EF1A-4196-BC1C-A22E983EBB1B.ttl
# 3E7341BE-CC7F-4A25-A8F5-58B7929BD05D.ttl
# 3F3AFE83-D3C8-4ECD-AD64-DA00161C2C6B.ttl
# 3F66061C-EDF2-4C70-A08D-D5C9FD5AD210.ttl
# 401F44B9-D41F-474E-8445-07140C70455B.ttl
# 4027997B-796F-4CF3-950E-7DA05B5DF455.ttl
# 404F58E7-4897-47EB-A96F-9407AB617DF8.ttl
# 4066B082-12C3-401D-A30C-F084AB769C9F.ttl
# 40675CE6-C65D-480A-B8BF-E313DDF39560.ttl
# 406CF09D-DF92-480F-825C-213097AE66CA.ttl
# 4089E48B-FDDE-4559-B13B-D908AE9634E9.ttl
# 40A29E39-55EA-4C60-A5BA-CB8866278117.ttl
# 40F74632-1020-4C50-84CE-A15980FC84A5.ttl
# 41293241-B51F-4539-AB48-621702AFEB6D.ttl
# 414EFB37-BCB2-4059-B516-54C278724D4B.ttl
# 4150C812-6792-448F-A223-8B3FFE241A9F.ttl
# 41AE0D28-F8C4-4A83-9696-D94A105FAA24.ttl
# 41E82892-D2DA-4AF7-9F6E-1A264784E236.ttl
# 42235E93-A8AA-4A96-87F6-BB29F6B8BC35.ttl
# 422A971C-1EE9-46B3-8EC7-362503A5B259.ttl
# 426E5EA9-6AAC-45B5-AE24-23A809A6DF06.ttl
# 429EBC06-9CDE-42E7-9FEE-C7EAE138DA6E.ttl
# 4388018D-F5B3-4F3B-88C9-022FD65CDA19.ttl
# 43CB22F6-B9FE-4F26-8C94-C7D5A0D4F8CF.ttl
# 43F8663A-BE70-472D-AB3A-D6A2E00999AE.ttl
# 4418DCF9-1378-43F7-95A9-F8A903553E25.ttl
# 44BD618C-4D79-4ED4-B393-360132B186A1.ttl
# 44D17E80-6FBF-442E-B04D-5C03E2CE93E8.ttl
# 4522FA16-39B6-4905-B82E-85E5F2E12673.ttl
# 45C00A71-F579-42EF-AF58-CAAF72F8A836.ttl
# 45C09ECF-B09C-4C1B-A219-45994028B240.ttl
# 45DEA761-9F3A-425A-905E-8BF5AADEFAC0.ttl
# 45E312DE-F230-452D-A3DE-672C682AC336.ttl
# 46700637-9F75-413D-9458-06E1AB6E4B2B.ttl
# 46E4C087-3576-4B6B-A42B-63F3C698E646.ttl
# 46E518DF-8D07-4A49-925A-FE48FA590DBA.ttl
# 46F0830B-3805-469E-B588-A5CF914DC161.ttl
# 477E5026-2C6F-4F48-97F0-3F2E30E76B53.ttl
# 47999579-AB5C-48A2-8C77-F0B1E60C8D7A.ttl
# 47D584E4-E67B-46FF-92D2-E70C534EABD6.ttl
# 47DB550D-5B9C-4D0F-BBFB-2ABD255DAC2D.ttl
# 4821AE93-F944-44E2-8E9B-1F1DFB397792.ttl
# 48224DF2-BC23-4267-B31C-298C97DD8918.ttl
# 4836EDD4-873D-4B5B-AB0A-94FB1C3B8E59.ttl
# 4861B110-3B6E-415E-9B83-1103634040AE.ttl
# 487B38A7-2A36-40DF-8816-16CB37640BD7.ttl
# 48A882BA-5D83-43DB-8B75-A585039CF054.ttl
# 4991A4B6-8D80-4D41-AF56-43E2030FD7EA.ttl
# 4A2E9BAF-C85A-4716-9177-181B42DE57C4.ttl
# 4A33C322-E59E-4E05-AACE-71DC6692D265.ttl
# 4A364234-E261-4C2F-A036-47A48CDE0D5E.ttl
# 4ACB616E-9595-46B3-AD42-45A4907317E4.ttl
# 4BC27754-AABC-4000-8B88-1C7BBE85EF65.ttl
# 4BD01287-E782-4280-802A-45509139972B.ttl
# 4C0D1934-447E-4DD5-864D-C48B9AEB15C4.ttl
# 4C14E064-809D-4216-BB93-A4EA602DE2FA.ttl
# 4C5C40BC-D853-4A53-9A43-38F05EAF1AC7.ttl
# 4C628A5C-EAAB-4A10-8FF1-2E01933EEE70.ttl
# 4CF468A5-C4E7-4FD9-840E-6F3C34A9BF42.ttl
# 4CF5BCED-F313-4B78-B3C2-244AC327855F.ttl
# 4D1D4562-13C3-4340-9860-5E54EB1694F6.ttl
# 4D7CE1B2-4EFB-4BAD-9C0A-C023A551DA1D.ttl
# 4F284670-8EEC-4811-87AA-0CA08185852A.ttl
# 4F481044-0FE3-467C-B11C-81B31DF27757.ttl
# 5002843B-34A2-4399-9E44-9D04F46D2AD5.ttl
# 509B3CBF-4EA3-4739-9B59-0D0A2149F46C.ttl
# 50DA8C11-CA79-46BD-A418-F0FE77AB996D.ttl
# 50EB00A3-5569-4B0D-B2C7-A6AF2ECFA560.ttl
# 50FC4CDD-5912-4E27-8866-206DFE72476F.ttl
# 51369FDC-F5F3-4B05-9E8C-B5169A711A2C.ttl
# 5140B75F-581E-4ED1-8FE1-35BF583F0147.ttl
# 5148F036-44DE-4E3B-BA05-BA2D8DE52EC7.ttl
# 51885C58-F51C-4D82-8493-B987A870ADBD.ttl
# 51A68554-D78F-4418-9576-E3706066B4A0.ttl
# 51B8B657-730E-4AA2-8EA3-5E17E6672286.ttl
# 51BD202D-6FC6-417B-A978-C2873FAA7D01.ttl
# 51E28FB2-5DA2-4B70-8CD1-ACF85C48AD20.ttl
# 52EA7F87-6A9B-4316-816F-1C0EBEE8C394.ttl
# 52EF709A-4E73-41C2-BEA9-654D3EA3805D.ttl
# 531E01AE-6836-4852-8DC9-47F34BD53734.ttl
# 536AED64-AA0C-4665-B921-3AA7FAB3BE81.ttl
# 538EC44E-1C31-43C0-9B0E-9951D6DF28C2.ttl
# 53ACEAD2-58F2-4AFA-B538-0E6ADB94A627.ttl
# 53C758EF-C605-4C91-99DC-8FDE4FB8E9EF.ttl
# 53F856F5-AE64-4B36-8F2E-4AF3064CF8CC.ttl
# 54106B22-A2E7-4D08-BF37-13524C59001C.ttl
# 542820DD-7039-4A87-B184-F88F2F77F590.ttl
# 545D8FB3-9FFD-42E9-B0FD-428B7E14A81D.ttl
# 54EB3C52-ED8F-4B2B-9A81-2C45732F7188.ttl
# 55D12E18-E507-4F4E-8A50-85E8FAD6AB92.ttl
# 55E8B435-C2EF-4E3C-9BDE-E272A3A8F43E.ttl
# 562536A6-4452-42EC-BD6B-ABC6F960DEA1.ttl
# 5649F6CE-AE1A-486F-8D12-5C1AC32FC92D.ttl
# 564EF63A-31DE-41BE-B2B6-26ED431F8F11.ttl
# 568CA381-F7AA-483D-BEE4-BE49C8CEA742.ttl
# 576A07C7-F160-42CE-BB21-AC6ABC4D9CCE.ttl
# 57C7B3BF-469A-4F41-B8F6-655F7AA1805C.ttl
# 57D3B1AF-0757-4E8C-9DA4-0A3DFBDE78DC.ttl
# 58153952-452C-49DD-BC08-65422457E521.ttl
# 581AEA4C-48DE-4F69-B0CE-7428F7C6CBC1.ttl
# 5844FB9F-F8B6-46AD-A522-884EF0D578C0.ttl
# 58E2B553-316A-4538-B743-9523A695F6FF.ttl
# 58EEC9DA-9C0E-4360-A316-D04780FCD2D0.ttl
# 5904B7AF-DCB8-4FED-8848-F592FA25FEAE.ttl
# 59708669-411F-4ED4-B8DD-D6F89C7BF3B7.ttl
# 5AA6B671-3D46-4287-A44B-C5CC51924B04.ttl
# 5B305C33-1536-49A9-9D52-A0F1D1E09233.ttl
# 5B8CA486-B312-40B5-9333-89718FAA2DCA.ttl
# 5BD11AA7-2043-45D5-8F89-A26D894DA22A.ttl
# 5C209B34-F350-43FC-918E-D4FF72D4ECEF.ttl
# 5D10A353-DAAA-4AB9-A191-CDA5E2329339.ttl
# 5D1D8F13-4EE2-4502-B808-2802E0E973F3.ttl
# 5D3F0A34-1280-4F36-997A-C2FC6A630292.ttl
# 5D6971B2-3069-4856-AF7E-06F1D6BA7326.ttl
# 5D9135B7-5AD4-4DD7-87BC-F98AE3F94A5E.ttl
# 5DB06B6D-AC9B-4440-93C1-FE47BADE82CA.ttl
# 5DD3BBA7-966B-4FBC-B080-8BEDB81F32D2.ttl
# 5E087E67-E931-46D2-B863-764E989825FB.ttl
# 5E17BFC6-D9A8-4757-9A97-C441394A76F3.ttl
# 5E4939D7-7C1A-4F9D-A2FC-27F384C7A209.ttl
# 5E528F81-3B57-4ABA-A9C7-11B367998A09.ttl
# 5E630A0F-DC16-4425-9DE9-E4DEB6773722.ttl
# 5E8BE9BC-5052-4919-89C8-FE98124DDA2A.ttl
# 5EB96AF6-EE6A-4629-A7DF-BDE7139ED229.ttl
# 5EC3A897-3AA5-495E-B38F-FC3944DDD6BF.ttl
# 5EF9D53A-F55F-4F9C-9A31-A4D8F870E7D3.ttl
# 5F10D51E-70F6-47F4-9E5A-A10ABE0E5FFE.ttl
# 5F4804EE-45AE-4D76-A3BF-17C4F71D28FF.ttl
# 5F71C956-BA42-448E-9B80-F3D3A07DF739.ttl
# 5FF796F8-25FD-4419-9A8D-6453EB1DE6DE.ttl
# 5FF83491-2C55-4D71-A1CA-A4EA6B4CA011.ttl
# 6002466B-AFB3-47E1-9DA9-AAB24627B673.ttl
# 60109A9A-D86B-4585-96DD-BE9DCC12117E.ttl
# 602B434D-7A1E-4247-9138-911F564612DB.ttl
# 602B807E-0833-41AA-80C2-26886D698AA2.ttl
# 60B570CA-C90C-4DED-9EC7-20F915DCA479.ttl
# 60D98802-5F6D-40C9-AFDC-EC1217BCA48E.ttl
# 6111561E-B84D-4F48-B0DF-43892C8A51DB.ttl
# 625D2936-A9B3-4B34-B2D5-D2D99D8CC3EC.ttl
# 626FABCA-206B-4128-BD1E-D2271808CA02.ttl
# 629891C8-9B1F-4496-83D8-208F4BA8EE5E.ttl
# 62A048F0-F170-4628-AEEF-1245C32DB77E.ttl
# 63B0B4D4-DFD8-4160-B550-ABAFB0269A50.ttl
# 6441265F-84CA-4A02-82DB-DDACB30B91CE.ttl
# 645C27D0-3483-4A9F-A340-7CF05AE3F011.ttl
# 64ADEDA7-19EA-4DA7-A305-6869DD2B08DB.ttl
# 64C6F277-C770-45E8-968D-75B9ECEE2023.ttl
# 6504CAB1-12C2-48D5-AE45-4289101ADADD.ttl
# 65A0929D-B104-4BCE-B324-CB7EAA9A391B.ttl
# 6601A14F-908C-4B0E-AB3E-87EB509C9C22.ttl
# 66BD29A7-44E3-4DBF-A11F-60B8941242C1.ttl
# 6832F543-6B9E-40DF-B16A-0EEB466DC0B9.ttl
# 68D693F9-3678-4C0D-8142-77C8FA611AC3.ttl
# 68F927BD-402A-4214-9B02-5CE99D488F9D.ttl
# 68FCD288-FC4D-4030-86BC-6A4C22C7503F.ttl
# 6948BC16-9620-484F-82CF-7BE03B53B970.ttl
# 69A8B1D0-2FEE-4507-9F3B-5EC7F804051F.ttl
# 69E7F2C4-277B-480C-A5B2-3C46778827AD.ttl
# 6A17BBD1-7B7F-409F-9648-02357361FBB3.ttl
# 6A341A9B-A10B-461C-9095-C512F7D219F2.ttl
# 6A448613-FFA2-4ADB-8EFC-A767212A1819.ttl
# 6A4ACA07-459C-4B74-8D2F-8A1FD72C2DFF.ttl
# 6BC1EED9-BD95-49EA-8895-6DC521F6CBD2.ttl
# 6BFD486C-0625-4FAD-BB21-273A28298DAB.ttl
# 6C129A87-44E6-4A70-9BE5-22484C34BFE2.ttl
# 6C6C205D-6B51-454D-A9BB-BA5FC9DF945B.ttl
# 6C8DBC00-78BA-49D2-B568-F6474E0EB37C.ttl
# 6CA6DB8D-1DB3-430F-A8FE-D80F369CB5FB.ttl
# 6D8BCA8E-1BE6-46B1-9056-002636699C8C.ttl
# 6D9BE172-EB17-44C3-8DFE-923883E56584.ttl
# 6DBF84AF-01CA-44A3-AB09-D63A02F32CCD.ttl
# 6DD6C505-7966-40A9-86B1-5EC09F32B1C3.ttl
# 6E458B8F-4566-40A1-AE73-CC31979EA6BA.ttl
# 6E5AE310-13F7-4CE1-AACC-3F06462AA432.ttl
# 6E6E76E3-2DB3-4AB6-9CFD-658AC5FB0142.ttl
# 6E74C0BF-25AF-4E57-A30D-17AC0708CF55.ttl
# 6EA43635-BEAE-483D-BDF6-0A033436F26E.ttl
# 6EDEB50D-9F09-4785-8758-C0CACE8F818E.ttl
# 6F42E1A3-6DC1-46E8-9A11-0DB491136D80.ttl
# 6F499ACB-AB4B-4DD9-8751-ABBAE7926381.ttl
# 6F62F260-096E-4E3F-B553-8B63333082EB.ttl
# 6F93F538-43D8-4C4B-944E-357C3AD6B766.ttl
# 6FB9AC04-175F-414A-B2FB-2807A512B950.ttl
# 6FE45AD3-851D-4E79-9D28-58480421C628.ttl
# 70089A4A-9570-4047-A9EA-BC20A1806884.ttl
# 70782B86-9BFA-4D33-873A-B63B76279F7C.ttl
# 709A03D2-4FEC-40CA-96BD-8E179979C85C.ttl
# 70FCD6CF-0291-422C-AAD0-6D4E3CD7C894.ttl
# 713A9966-C921-4F6F-A708-306BC4BED6D0.ttl
# 71A3815B-30B3-4085-8AE7-7A8901DC8B92.ttl
# 71B18103-D60D-46AD-B69B-713E5E5554DE.ttl
# 725199B4-24D8-47E8-A46B-3592E0BDCD4D.ttl
# 7284AF6B-D854-4116-9ADB-DDFD7B2DB9BD.ttl
# 72DAB2E3-57AA-488A-B229-2203542B1659.ttl
# 734D88D8-EF7E-42E0-B335-6AE688DB0124.ttl
# 739FF6B5-BDF7-4A93-AAEC-921006E64EE6.ttl
# 73BF8097-73BC-441E-ACEA-CF3015E8F57C.ttl
# 74522043-223B-4F21-B5C8-9F730A0AD960.ttl
# 7498FC99-B1E2-4EDD-AE3F-B37245A7DDF7.ttl
# 74A20F59-B077-4BB2-9D4A-8980170351DE.ttl
# 74AF82E0-038B-4A50-937C-ED0C847D08C8.ttl
# 74C35363-C888-45E0-8D29-04DFDA261B8B.ttl
# 75AD464D-753E-410D-83C1-1C137B33DB01.ttl
# 75B5C120-F2A9-4DAD-B43F-B0F2A795CE74.ttl
# 7658633E-899C-41E5-B57B-D453DE76EDAD.ttl
# 768DE745-8D86-4F04-A6F1-78A9FF71A522.ttl
# 76F84A3F-3619-414F-8E9B-792CE949BB6E.ttl
# 77160E1C-EBAC-431A-BA9E-F8574B827C95.ttl
# 77850F89-E85E-4A24-9F91-2F546EBB8B38.ttl
# 778C1099-64F1-4581-8E0D-F353DB87C266.ttl
# 78062307-780B-4C6C-B049-960E1CD1FF3B.ttl
# 78856215-E4B0-4406-9972-0BBADA9138B8.ttl
# 78C7CD7F-84AF-43B0-A0FF-912995647C6D.ttl
# 7942F490-79A0-407D-82EB-06A05777E408.ttl
# 79453821-896B-4B24-82D0-D05DE440FEE3.ttl
# 794E66BA-9F78-474F-B49D-DDFAA126E63D.ttl
# 79BDBC96-10A8-4E1B-8E68-1E6DC9E1A834.ttl
# 79D8F246-C2D6-41AF-A10D-D27E94F4A80E.ttl
# 79FCCDDC-425D-4AFE-A1FB-90AED5AA77B4.ttl
# 7A3C64FE-A856-4A12-B0D7-FB4F6A613161.ttl
# 7B30F5BD-BAC0-4EE8-80C8-88320041A081.ttl
# 7B51D217-5AA5-4319-AB6C-8FEE01CE0F38.ttl
# 7BE385BF-026B-4742-ABBD-EB9858180756.ttl
# 7C3108AA-4A37-49FA-9CD0-A0BDA924F9C7.ttl
# 7CB691CF-CB08-4151-BC15-623DA149A74A.ttl
# 7D198701-8916-4B34-BBB4-B553BD7DC973.ttl
# 7D5B2861-2514-478E-8F9D-7938D77971E3.ttl
# 7E1BAF4F-BAF6-47FF-9489-30CF259D4FAE.ttl
# 7E29F8ED-407A-4A23-A307-2EAEA2C00AF4.ttl
# 7F4C2E6D-EF41-4CBF-AC54-31B49160BB65.ttl
# 7F669739-A618-4847-9C1F-8450337DCC33.ttl
# 7FC8711A-46F4-4F69-AD53-DEA96F878890.ttl
# 802B57BB-8C1E-4D59-85E6-1C111CE8EDB2.ttl
# 80DF032C-7DB6-40A3-807B-63E9DAB8F270.ttl
# 80F45BAD-5720-4C49-88FB-DDBE3C0FA3D3.ttl
# 8125B1E7-4E5B-4A6D-8843-79E8DFB2CA56.ttl
# 8183F780-D62F-4614-8899-C4BCEDCA9492.ttl
# 81A7B240-D982-4E20-8799-FC17182EC671.ttl
# 81CB8BCE-0CAE-4E47-907A-86CE0BDA3751.ttl
# 81F1B49E-6F04-4D3E-8FE8-0E07E346491F.ttl
# 81F52C6F-4446-4E17-A3BE-F9CEF413E172.ttl
# 821CE343-2311-40B2-82E5-FFEB45E229B5.ttl
# 823EC749-7EB4-477C-B4FF-C8A56338F0F4.ttl
# 8241526E-BFD7-4CDE-978A-FD5CE1A74970.ttl
# 82A02CD8-AD13-48E3-B1F0-9F5C437E0D5F.ttl
# 82AD2BE7-81E4-4319-8D2A-5405B37AB664.ttl
# 82F16684-1F57-41D3-BBC2-3B997D7D3B6B.ttl
# 832127CF-58EA-4961-8D38-13885E29B637.ttl
# 833CEA33-615F-46FE-8891-8DAEB4F984E6.ttl
# 8377F5D7-FD67-4253-AB01-6ABDE6C48A44.ttl
# 83ACA09D-A65C-4C3D-8FBD-AA52B52DC8AB.ttl
# 83C7C6EC-43A7-4D3F-9A5F-2C438BDF9410.ttl
# 845EBC82-1D9B-4270-9A73-F51AE5343EFA.ttl
# 84625AA4-6DB5-41F2-971E-A25AAC40D550.ttl
# 848793F7-94F7-483A-B48E-AAB119BFCEE9.ttl
# 84C352CE-BB8A-4448-BDF7-C6A36B7022DA.ttl
# 84C51F7C-572A-4C9D-A5F0-35454FF67741.ttl
# 85854CA7-8AE7-4967-A27A-59C8583313DF.ttl
# 85D58DF1-3984-40E8-9899-01A556B19CA4.ttl
# 85FB5237-6ADB-4C57-A38F-66F6B2AD9B40.ttl
# 86163804-CCB7-4B9B-BB92-62450E1515AB.ttl
# 863A43F0-C506-444C-A4A2-2AB6C61EECBC.ttl
# 868F0BAC-5D9F-4DB5-B74A-A4B40618E76F.ttl
# 86904717-CF73-4914-AD7F-71B99AAC2805.ttl
# 8699B201-6391-4E0C-9829-5634EBBC6385.ttl
# 86D4E531-FC74-46BD-A115-0B83ACF66AC5.ttl
# 86E6BE1E-3DEE-4152-91C7-F651DBDC815C.ttl
# 86F60D1A-2504-4439-9939-DABA41797C55.ttl
# 876DD010-1552-44F5-B16C-4593A047CB51.ttl
# 87EB80C4-85E8-4898-A920-FBA116D8B54F.ttl
# 884381CA-4713-4B2B-BC58-FFB5F7769977.ttl
# 89262E98-70B3-4DAA-A17F-8D63E5550924.ttl
# 8957B893-C510-4776-A465-A5C59BD12DD1.ttl
# 8BA3B20F-871F-47FD-8F6B-3E6BFCE90245.ttl
# 8BEC22AA-7EDC-4D3A-B325-E2CB4D27E279.ttl
# 8BF515C7-0CA8-4B38-8079-21DF66FDC532.ttl
# 8C4B917A-0271-4CFC-89A2-596460A7142C.ttl
# 8C4FB6AA-167D-4BBE-B4CB-37DCB61494ED.ttl
# 8D4957BA-BFB5-4A74-9B07-CC1195B58E13.ttl
# 8E4153F1-8C75-4082-B824-1211D4B8D9CF.ttl
# 8E5087BA-DEBE-411F-98DF-6B5ADD503999.ttl
# 8E684F40-53D4-4ABC-A261-FF65BD2EB3E9.ttl
# 8E9DBFA4-B983-475E-8AFA-131BD11245AF.ttl
# 8EEED749-AEBE-481A-B8E8-7FE5D8E8C0EC.ttl
# 8FB25644-5F3C-4EB7-9980-CF97FF069413.ttl
# 8FD863C6-E78A-40E6-A85A-56B9C1590A34.ttl
# 9075FA49-9683-42BC-9980-E8A85C0D1DB2.ttl
# 90E33F3E-7F9B-4AD8-9DE8-94CD3CA0C204.ttl
# 90F169CC-8183-4D0F-884A-4ED17617F7E5.ttl
# 9108F579-D2A6-450C-BB50-B31DACD646DD.ttl
# 91402C91-A1F9-4553-B879-BC4265874F3E.ttl
# 9147490E-0BF3-46D0-A3E6-7602FA8350CF.ttl
# 9194FFFA-51A0-4E98-9F4E-7174B0EF7CB6.ttl
# 9213E3F3-9958-4651-B54C-1E9556C2C705.ttl
# 921586A8-9438-48B0-851B-C41380CE8B08.ttl
# 924A13F6-E030-43B9-8B5B-941042B740B8.ttl
# 92761DA6-27E0-44C2-82F3-D10ABFF2F07B.ttl
# 9334A8D5-DA3F-40A9-85E8-983AEEF7F334.ttl
# 9367C3B6-7E75-487C-BD2A-A6DF87994329.ttl
# 938F7AAA-FCB7-49EE-8951-196A9C843BCE.ttl
# 9499C675-0423-492C-8545-0C6C7DE154E9.ttl
# 94D61AA7-6741-4A55-A9E9-125445E2AF28.ttl
# 94DDE03D-1C3C-45F6-A8F9-8661FD7874DE.ttl
# 950924A9-1D4D-42CB-8A29-28F0BEDD7653.ttl
# 950E055E-E4D3-4A18-B0E0-2BC07358639D.ttl
# 95944158-54E1-4C54-AB2F-EA7D719692CE.ttl
# 95ABB16E-E6E4-4432-ADFE-83DFE1F2BAA4.ttl
# 966CF7F2-F446-47B5-AF74-619B4DCAB4F7.ttl
# 968F6571-2B5F-473A-A13B-C2AF0C63B64C.ttl
# 96BEB899-7786-4503-8F67-C80ABC844340.ttl
# 96CBCC3F-6254-4C60-9EB3-632370A5E491.ttl
# 97063325-FD5C-4BF4-92BC-44BB88FBE8AA.ttl
# 97981029-0FC4-4BC7-8C39-40B68AFDD8A5.ttl
# 98503B5F-6AE7-4C93-9289-3F7128A4B429.ttl
# 9A4B5462-2CE9-441C-8844-C2FED09477A7.ttl
# 9AEAF930-9A24-426A-AD6C-57599552B7A0.ttl
# 9B2AF366-1DB6-43B0-A321-C5599B8D7AE8.ttl
# 9B34BA20-8CC3-4FCE-8717-91AF95452CA1.ttl
# 9B4A9857-2B1B-484E-B84A-6AEDC6F04651.ttl
# 9B9F35D2-4D0A-45AE-8DA8-A3AF071F6B71.ttl
# 9BDB850B-EE09-487A-8DF3-7C9F003118B8.ttl
# 9C95A4B2-9F78-4C33-ACF6-FD7F6E11597A.ttl
# 9CF41CE0-3B1E-4E1D-81A9-F81037AF6652.ttl
# 9CFFC9A7-FABC-4976-906B-9573DAA098DD.ttl
# 9DA11F3E-7CA4-4127-9BB6-E9FA8FF08E9D.ttl
# 9E1108EA-98D1-4D2B-8811-6A474C3BED20.ttl
# 9E383E8A-9E73-443E-9639-32BF7DF971A3.ttl
# 9EB95B82-BE19-4785-8AC6-D61F2C40262F.ttl
# 9F40C6FB-D95E-4963-BD36-2A0C5F1E4834.ttl
# 9F520FA5-DCC8-45AE-82F7-E5A73C5EFC22.ttl
# 9FBA3417-BA9F-4DF5-A57B-B0BD81641B61.ttl
# 9FE81173-0667-4A6D-86B1-067E799DCAEF.ttl
# A0305C86-7DBA-4D99-A347-CF829C9EB1E3.ttl
# A0AC650E-AD61-4826-A025-6DF5BAEE9670.ttl
# A0F2FDD1-331D-4DA8-94AE-5D5C36B014CA.ttl
# A1222811-A6DD-4D38-9B97-A1CD2C9E3E63.ttl
# A148C4E4-911A-4549-BC9B-33E79E111259.ttl
# A15D8275-D013-4BC6-99CE-E155E6260C86.ttl
# A1A71FAF-D4B1-4ED0-AFD2-939F0DB79148.ttl
# A1F6735A-2D4E-4AB2-8FD1-6C0F9DEFF63D.ttl
# A247196D-750A-45C0-920E-ECC3E3A89D10.ttl
# A275C631-C7F1-45E1-8D8C-039924FEF152.ttl
# A29B3350-5870-4E7F-8F20-F7F01D91DD38.ttl
# A2A2867D-54EC-4782-9C10-9243FB84C980.ttl
# A2B54B07-102C-422C-B6A3-9C6C3315F5DC.ttl
# A37C6CC5-8AB8-429A-876C-045DB5E0C6A5.ttl
# A394F364-1E46-434A-94ED-5109DCC3B4EF.ttl
# A3E843F8-0556-4B5D-B540-95B3DBA84C0F.ttl
# A42DF733-A1C2-434B-B1EA-6C194E92E5CA.ttl
# A45B1557-3332-4DFE-BC8E-AE5B6777C2E3.ttl
# A484EBC7-2EE2-45C9-9961-911E213E4A48.ttl
# A48588B6-218C-4375-A6B6-FFBFB7C6EDFE.ttl
# A48C4AED-34BB-4D65-B24C-69E8D13C9F72.ttl
# A4F6A31F-DBFF-4196-BA29-C3881252997B.ttl
# A5435C36-FDE0-4820-B9CB-999528DC9292.ttl
# A5EB3913-8548-438B-BC10-4952734DA1EA.ttl
# A5F5007B-8021-4586-B5E7-3FCD07FA475A.ttl
# A65CBC93-FF07-438C-BF2D-E340BB76BFAE.ttl
# A69D73CA-8C2D-4433-ADF1-B0FF12969B15.ttl
# A6FB3637-F55B-4762-864F-F4DCB5695AB2.ttl
# A701D140-0C51-4314-B891-6C8B5F560517.ttl
# A727C742-3ED8-4E82-B7AE-1A2779022FB1.ttl
# A74599A4-F1A2-43CB-99F9-B9035C0C65C6.ttl
# A7CE57EC-F7C8-41B3-9B6A-B9F41EC57DEA.ttl
# A817B2F6-F9C0-44BC-9007-BF42E4F7A604.ttl
# A84F85D7-36A8-4C97-A569-9A0194A614EC.ttl
# A85A8307-87F3-4FD7-8BDE-EE6CA3C9EE6F.ttl
# A8CD3CA1-A72D-4D43-8B88-B32196131A97.ttl
# A90838AA-3D93-47E3-BF6F-61A9B41386A3.ttl
# A97352A5-9AE3-498E-A483-398BB2F27EFE.ttl
# AA2EEAE2-96CE-4E0C-A835-A9B76215312A.ttl
# AA371074-4A49-4F40-AD42-401A4F60EBEF.ttl
# AB9DEEF0-FDBF-4AD6-9E06-C9A606CBE97D.ttl
# AC57F734-DC4A-4203-BFC0-FC0A772CC6A3.ttl
# AC78B5DB-33C8-421B-B340-104B16FFDA84.ttl
# AC8E1E7D-ABB9-4FC2-8324-CE76C509CB7C.ttl
# ACEE9FD5-6102-454E-8FF7-083AAD2DD3B6.ttl
# AD06DAC5-9D6F-47F5-8CAC-65F99F213CBC.ttl
# AD8677A0-771D-4C13-9794-9778F4451D74.ttl
# AD9E34E5-BF7B-4C74-B771-7024B535CCC9.ttl
# AE3A6FFB-DA55-4334-8B1C-6C1A2F13C351.ttl
# AE40091B-8E65-4091-BBCB-999539019CB8.ttl
# AEB2CD27-F45C-496E-A075-ED1C94C01F03.ttl
# AF1CB2E9-CA1F-458E-B3A8-6D960A728DA0.ttl
# AF276F45-C9BF-43EF-AFFF-D598F6BAC2BF.ttl
# AF45E810-8854-4423-A223-A6B17DC5A8FA.ttl
# AFB69A84-DB61-414D-9F79-1277167736C4.ttl
# AFD6364F-D2AD-48A3-A748-7F4096B060F0.ttl
# B04E3E9F-011A-4AC0-BFEB-DE1EC5F8DD36.ttl
# B09C323B-E757-4AEF-866D-4DFFB560C4EE.ttl
# B0DA751D-32F6-4A02-8B4C-CAB50AD13418.ttl
# B0EE8A7F-EA97-432E-81FC-737949E8EF18.ttl
# B1715220-236D-4BC9-B2D1-C5803D2FA992.ttl
# B17966C7-C104-4965-907B-C1813402E6D3.ttl
# B1A1A8C9-FE59-414A-90B9-963A48165120.ttl
# B1A4A218-BC64-451C-B5B4-910A9CFCF209.ttl
# B2515991-1C5F-46A9-B938-0E92E4B70CA3.ttl
# B28A1B0C-7F9B-4A93-885E-30A8545CA01F.ttl
# B29FDE31-29C4-4DA8-BDF0-304481BF06EA.ttl
# B2EDC6C8-F565-402B-BC0A-9B07D0885FDE.ttl
# B3AC0230-F1D8-4833-9481-7F8526C28C6F.ttl
# B40CC917-4D94-493C-925E-1E103706F1EA.ttl
# B48D77F1-5D61-4300-87AF-E490632D3F60.ttl
# B4A9CA48-C8F0-4AF4-A99C-3C6F546F7623.ttl
# B56C57B1-F1E7-4591-9AA3-8FF1B595DFF0.ttl
# B571BCA2-5566-4FDD-9691-4871EAEB983A.ttl
# B59A3992-58C9-46FC-B378-A3CEC01911B8.ttl
# B5A4AC94-91AF-4CDE-91FC-B01231C1DAA2.ttl
# B6657B67-B16E-4582-9A26-6852F6D6B948.ttl
# B6893552-6329-4A2A-A771-671140A937CC.ttl
# B70F4B77-4E9A-4006-A023-207CE28558FD.ttl
# B76B4611-B1E2-4DF9-A8CD-84BCAA87F291.ttl
# B771962F-5136-48D7-B168-76E0E5B62261.ttl
# B823AB99-5FFB-4F7F-A039-8D55110D869A.ttl
# B85B1757-179A-4E54-8126-5168B2DA778B.ttl
# B88772CD-1FD4-4771-AD41-8D5C6D177B2D.ttl
# B8E7D484-B719-4402-A21E-877B6406BBDF.ttl
# B9148848-B332-479E-9928-8732F7DE7A3D.ttl
# B9258C39-EF41-4E49-87B5-60969BE5BFDB.ttl
# B9DBABF7-464E-46E9-99E1-9C95D6F8D13F.ttl
# B9E07D9E-98FE-45FE-A7ED-399D988AA326.ttl
# BA25B3FF-F6B7-416B-A6CA-1875DB85AF9E.ttl
# BA67502D-593F-4650-9C7E-CDCEC060547A.ttl
# BB817775-7652-4989-BCF4-0BFF2E8A259F.ttl
# BBF148E9-9294-4D9A-86FE-3A43C7BD68E0.ttl
# BBFD2223-E197-4854-9A23-9BD8D63CF66E.ttl
# BC970458-50D6-47F0-AE31-D7D39350A52D.ttl
# BCD96E64-1067-4791-AEA2-5A887B8A532B.ttl
# BCEE6CC9-21E2-483E-A90C-6FD9E043409C.ttl
# BD1FC688-41ED-439E-8F1B-EB9FE8BE8CA4.ttl
# BDCD3205-7EA1-41ED-8954-8E812CD73975.ttl
# BE36768C-6708-4E35-A37A-AA7692D73D3D.ttl
# BF155D61-478C-481A-8A86-F43793C5933F.ttl
# BF3C5C24-2203-4102-A4E3-AF6B6BF2F69D.ttl
# C028AD73-F065-4EC5-BBDE-071FD7E8A66B.ttl
# C099C8F7-77A2-4627-8545-67BBA1C2FC1A.ttl
# C0C74EDB-C9D0-4D75-92FB-FB5F8F8CD9D2.ttl
# C0F65612-9B2B-4DDA-9E7C-264DA4452263.ttl
# C1384986-B54A-4B46-AC59-ACA2C122600F.ttl
# C151E0BD-B9D3-42C7-9712-1C1C30DFE328.ttl
# C1AA6032-3B80-4B03-8853-08BD167F9643.ttl
# C1D5A6A2-FA18-475B-ADA2-E5FF9968D092.ttl
# C22A4592-F9D6-4525-97C0-85F936CBA957.ttl
# C2352FC0-3650-4BD1-A063-0C44A1B4EF64.ttl
# C259ED8A-F189-44B6-A75C-A40E6D9A5D0A.ttl
# C2E5BB88-1376-4663-BBAE-C7375422855F.ttl
# C3F57408-5DFF-4EFB-99C3-2D76ADD728E1.ttl
# C41979AD-E8FA-48FB-9B94-1EDD10591851.ttl
# C451BAB8-AF33-4FFD-927F-E429D4654DB6.ttl
# C47916E4-2FB1-4028-9660-F2D4B5026987.ttl
# C4C4E5F2-F59F-49EC-B63A-23D647938BF4.ttl
# C583234A-BDCA-462B-A75E-16BD6526B6CE.ttl
# C597C9BA-57CB-4D9B-81CC-CCF4E00F948A.ttl
# C5E135B7-1038-4A6C-84EB-444D033426A0.ttl
# C6C1A406-C678-4A6F-B562-5B9C74908EFA.ttl
# C71CE12B-0D8A-40A6-B646-D4D042DA8749.ttl
# C7838AA9-D9E6-4F78-8F08-E78F99FFDFBE.ttl
# C800DCEE-D8F5-4FF3-B042-C03D3976A02A.ttl
# C82FC710-489A-45EB-82E5-673653B6FA2D.ttl
# C85E580E-31E5-4F94-A497-A2743A17D52D.ttl
# C86E1578-E78D-4AC0-8062-91BEF6D31900.ttl
# C88D2079-B5E8-47A6-B4FA-A67ED17FF9CD.ttl
# C8E5774A-45D4-45A4-89C5-0E92E89BC0AA.ttl
# C954B10D-ABD8-4DBC-B5BF-D7A5215F3C5D.ttl
# C97F55CD-8643-45E0-8D7B-D8408E2F63B1.ttl
# C9DD7E28-4738-4C85-9861-DED14F7B1A11.ttl
# C9F74F3D-2C94-4CD4-886D-0622EB062A56.ttl
# CA0EE1C5-192B-43A2-B3C9-1DDDF42C6DAF.ttl
# CA9D13A8-9CBD-4EE9-A514-EED1422592CF.ttl
# CAC2BF17-F3E9-4C68-BD94-D061FE89E7A2.ttl
# CAD89F97-F2FA-46D6-B7AB-9C256F498240.ttl
# CB11142A-071F-4DD0-A914-E17C1138805C.ttl
# CB43D03B-044F-40B0-9329-8A5D0716FAC7.ttl
# CB73F709-7D76-4BFA-80B6-71A575658DF2.ttl
# CBCCDB09-A8C7-4BCC-9443-575E613A5617.ttl
# CBDE3C1F-FB2C-42F6-B5F4-CB875F43F35D.ttl
# CBEAE372-6669-4210-A59C-5B3EB102953D.ttl
# CC5E6A3A-8725-4B5D-8AAA-58C43D19B162.ttl
# CCBAAF27-F575-4EF1-9E75-DDCB1EA24838.ttl
# CD748C7E-4FA7-4102-8635-A639AFBCA69F.ttl
# CDB8A5D7-8466-494E-9EDC-74FD2F17DBB7.ttl
# CDDA4474-B334-49FE-A2B3-56988E3C7498.ttl
# CDEC6C25-8898-46F6-8A74-685EF0766E12.ttl
# CE76F595-6ACD-40CD-B678-24EA53D51477.ttl
# CF51D856-6FC8-4492-8C96-342B45909AE7.ttl
# CF85DC87-CBAF-42A4-8442-8AC76E1DD614.ttl
# CF89309A-4BBF-4497-A0AE-DFB92931BFCF.ttl
# CFD14F9F-9543-4943-9ABA-C9DDB306C6B5.ttl
# D02CF52D-054F-4923-AAF7-4CB61C502F95.ttl
# D04F5854-6439-401D-86D7-B355F0185868.ttl
# D054FCD8-2A67-493F-A03E-E224FED88CA2.ttl
# D1337D0B-8440-48FE-8EB4-EE1ECEB6586B.ttl
# D19C5A44-3847-4E21-9A34-1B8E7030400E.ttl
# D1DED9C6-A250-4C4E-8C9F-FE77F5F0396E.ttl
# D267BB05-6B78-4D03-A7E1-9DAA6F7BF5A4.ttl
# D2BB9181-16CA-442B-BD85-1080A510C1B6.ttl
# D3117F5F-111A-47DC-9FDA-E38DABF33C19.ttl
# D39543BC-DF3E-4F2A-A029-952B6C0FFADC.ttl
# D418F84F-B5A9-4843-BACA-F52012D7B37B.ttl
# D4489B0D-D389-48FC-876A-E0ACB0721D82.ttl
# D4AA9F0C-46AF-4B54-B5B2-AFBA89E85682.ttl
# D4B76518-B0B3-4B54-BC9A-A8D14CDD9E47.ttl
# D515D8FF-93F1-4CFC-AA42-8624CF191225.ttl
# D531F4F1-EC87-4C03-9058-D11D6FFE6A1F.ttl
# D55BFF58-EE5D-44C3-B5EB-FE194C6D2CDA.ttl
# D57F33E4-76AB-409C-B957-CFBDC83AA48F.ttl
# D5AC0A28-B975-4C81-BA91-62CE09F2AA29.ttl
# D663E866-2488-4847-9A5E-C71B77CAA619.ttl
# D683BF9E-B75D-4C85-913E-4C66B5B26669.ttl
# D6DEF337-B735-4E08-8363-7F549DDFF67B.ttl
# D6E9817E-28A8-4B1A-A040-ADD622E620AE.ttl
# D6F510FF-FFA5-4F04-B4E3-EC4ECE3880B9.ttl
# D708F2A8-BD8B-466D-9327-E89382734712.ttl
# D70C9A73-E37A-48D5-9E8E-C068AF66DE0B.ttl
# D787252A-7761-493D-B17C-411243A9DF4A.ttl
# D7D6CA9C-2B9A-4C3D-9A0D-3666F4DFA37F.ttl
# D7DB44AC-C46C-4D14-AD94-3AED44BC4843.ttl
# D7FD4A59-39EF-4C0F-81DF-3FAF1105C555.ttl
# D83A7570-DEA6-48C2-8475-B94C903C90A7.ttl
# D856AA4D-31F0-4C87-AAFC-0D7E7A35E783.ttl
# D8DD3D02-EB3F-482E-8BC3-029FEB10DCB8.ttl
# D97B0DEA-FCAC-42C6-AAD6-29FCD21E883A.ttl
# D9A958F6-821F-4784-82C5-B007A185F4C6.ttl
# D9F4CED4-A4A8-497D-AE38-F21C8ED27028.ttl
# DA0DD686-2338-4D03-BCEF-8CCD6BF3E3BF.ttl
# DA18B287-DDFE-4535-ABFE-787E87ED8B11.ttl
# DA7643CA-721C-4A0F-B9A2-43B50AF9D867.ttl
# DA77B7E9-FCDE-4C64-80C9-A73F983927F8.ttl
# DAB7FDB7-0A34-43E4-9867-B0FD48EDEDFF.ttl
# DAD26B73-4ADB-4798-A4E8-516505D1DDFC.ttl
# DAE7C14E-0EE7-4A84-B5B6-C18598232C21.ttl
# DAF6ED1B-256A-4AAB-A2AD-4B6ED8B70715.ttl
# DB4D9E39-8545-4752-ADF6-AF9C2E3920E6.ttl
# DB58BA30-C20F-49FB-B29B-1AA9ABFBBAAC.ttl
# DB62CEF7-B73D-428A-B88E-8C0304AF1C8D.ttl
# DBD2D24C-9990-44E0-AEAC-23E07800201C.ttl
# DC123877-43FC-44A7-98EE-72809F7F0D0A.ttl
# DC3E2A53-44A0-45EB-9F21-FDF062677431.ttl
# DC5A4DE0-199B-4AE7-95D5-705A44B83224.ttl
# DD2E6ED9-146F-44E4-A0EA-4C00AB2BD02B.ttl
# DD4691AB-A8F5-4659-AA0B-4A0AC4073E61.ttl
# DE2D00A2-3C7E-42C9-8749-2B3991FE4A1F.ttl
# DE902AC1-20DC-4F6B-8EDB-6B69DC5FD0EA.ttl
# DEB3C46D-0C47-4039-A30D-A10D3B3B0BE2.ttl
# DEDBC2CC-5A18-4A94-BD18-FA9F5EC4D7C5.ttl
# DEF5259C-FA03-4443-9550-546C65A88145.ttl
# DF54445A-6584-4F53-958E-3820A8A33272.ttl
# DF8754B7-2F8B-49BB-B46A-DED6C5BCD47F.ttl
# DF9DCD89-0627-4945-BDD5-6B7B92CA7F84.ttl
# DFC94587-E07C-491E-88E9-F90BEAA8F1D1.ttl
# DFD1FFF7-7263-4093-853F-51EB9A76DADB.ttl
# E00436BA-7E17-4B38-BD62-22A6E3D78930.ttl
# E01AB47F-701C-46FA-99F6-9CDCB401E0AB.ttl
# E074015A-0698-44FA-8220-B5233EE71C58.ttl
# E0C5DCE9-0518-4178-A47C-8C8A34C1B353.ttl
# E10C9B4B-C0CB-44B1-A84B-9D41C3918F04.ttl
# E137B514-D720-450E-B903-9F186D947342.ttl
# E1BE7635-B8A5-4DAE-B766-D55613E25A67.ttl
# E1C8540F-5014-4091-AA38-2AB6C96EE226.ttl
# E25BA504-20D2-466A-81F1-284D1A64D8B2.ttl
# E2D2F674-85F4-4C73-A295-BD5D2A196338.ttl
# E2DA9A92-947C-40FD-B20A-69CB5C7E23F7.ttl
# E368DFCE-28E5-475A-A1E2-77833F5261B2.ttl
# E3C57D5C-8EB2-4A66-9E5E-47B17A4ED924.ttl
# E46FCD1F-A6E4-4086-B1C5-24B0633C6334.ttl
# E4B79293-53C3-4FE8-96B3-C26B4FBC2237.ttl
# E56DB6B2-E374-4DEB-AD4B-FC4D482470DA.ttl
# E589EDEB-7FAB-40BC-B336-A155645AF627.ttl
# E5DC12BF-EFC4-4932-9AD2-0A8C797A409F.ttl
# E603E483-CA9D-454A-A395-4581AECBC1C9.ttl
# E69E0A28-B798-46C0-A2B4-AE137949E358.ttl
# E70B4BC3-7A7A-421E-9E18-78C58F793F06.ttl
# E72134DE-5F9E-418C-A2C6-63DB07F6A3B4.ttl
# E7396B43-80B4-4AFC-9591-9F738A4052BB.ttl
# E756AC7F-5997-4CE8-8BE6-DA4C3F7C7D66.ttl
# E7E7505B-9633-499F-BA01-26526634C026.ttl
# E7F211B4-53FD-4AFC-8793-23DD16D4C3E0.ttl
# E83F45AD-394F-4A8C-BDC4-B0972055824A.ttl
# E859CA15-70CF-45E6-BB2A-FC80AA2756D7.ttl
# E8A98018-7A65-44FD-AEC8-4024B99A2AFF.ttl
# E910DBE1-A979-42C4-9029-25B6B3257C29.ttl
# E98D8494-2FFB-43F7-9ABE-E3DB1FED1F96.ttl
# EA27777E-29D1-45EC-A694-3D16A4993F55.ttl
# EA39463B-EBF9-4901-9F56-6C30DADCFF55.ttl
# EA45E237-F9F0-48BE-AD53-46F7ABAEB1B6.ttl
# EA881A23-9757-4165-A15F-573A3E080BBE.ttl
# EACEE4D7-888B-46D9-90BF-9B0CA249C988.ttl
# EB3D1C2A-255A-4CA1-B217-829DE702C615.ttl
# EB3E05C4-0AB7-4016-8250-0233B7A5E5D4.ttl
# EBA3688A-81C5-4406-8C75-0906010E1883.ttl
# EBB6FCC7-1AA6-4568-835D-2F6DBA5B1298.ttl
# EBDB8990-1672-4D1C-8508-380B12016DF2.ttl
# ED164613-DCBA-46E0-A651-68D72293E995.ttl
# ED2A0D07-485E-4E6C-8690-12AA508663D1.ttl
# ED99CAAF-6BCE-4009-8C34-654CC1DEE6FA.ttl
# EE329D95-E6E5-4DB6-97A2-028E6E0DE98A.ttl
# EE36FC12-DDD4-4B51-8830-4CE5039ED70F.ttl
# EEBB1FD2-4176-4E1A-91FE-121D2D5ED801.ttl
# EEDBF463-51CC-4D77-81FF-DA3F13F08174.ttl
# EF15669A-86EB-4E3D-8483-1105EE5FCAEF.ttl
# EF386170-8EDF-4108-A45F-A9463E807486.ttl
# F02F3CA4-9CEE-4219-996C-405E6230CF32.ttl
# F032AA7E-75C0-4D90-83D3-A6064F4412DA.ttl
# F041E5DE-F6E7-4EBF-888D-0B7B0B861E67.ttl
# F06E19E6-86AC-4DE6-BD6D-446C231E8478.ttl
# F0701403-8FD3-44FE-8FD4-82F69750D629.ttl
# F0820120-F3B4-441E-AABD-58EF92B85CF2.ttl
# F0A2A1D1-FB98-4560-BBE1-FCA889014DD2.ttl
# F12FE5F6-6F80-42DF-B291-CEB9B799C3CF.ttl
# F165CD84-96DB-442F-938D-06FFFCA926C9.ttl
# F1945BE4-A928-43E0-9177-1690F3E49643.ttl
# F2076FB8-2ECD-400E-B966-6778A7C2C7A7.ttl
# F23F4B7A-7D07-4D54-8F4D-6E9DDB8CC48F.ttl
# F28AD168-9DD3-409F-9749-22B7DCE4E16A.ttl
# F28D5E66-D5FA-4FF4-9216-B850FBA0A3FF.ttl
# F294137A-D6B6-49EA-88B4-D990D7049F25.ttl
# F31C1FF5-23C1-4DC9-ACD8-B7205583C741.ttl
# F34F3814-6DC4-4888-8914-CCAAD96FA4DB.ttl
# F3EA5ED8-884A-4222-ADC8-519EB4444679.ttl
# F3EEEB53-A360-49DA-87F9-8027E1E64C7C.ttl
# F42B78A1-D674-4A88-A948-1C7A43AB60D8.ttl
# F4391760-C600-4554-8509-A64D1E1D4F07.ttl
# F47DB81C-6BE6-4C09-ADE9-5D49715C1372.ttl
# F489749E-A294-4E5D-8953-6BED11DDA691.ttl
# F4E5EB30-56F5-4921-B7E5-10E427C7C71A.ttl
# F54BEDFE-BBA1-41E6-8735-49C534EE6441.ttl
# F54C1CD5-78A0-45D3-B541-160419A83805.ttl
# F5EF3C16-30AC-461C-8F68-167D324E131E.ttl
# F60CAC27-4CE3-4936-A691-835B4AFC68E6.ttl
# F6590E26-4255-4906-8446-F2FCA607048A.ttl
# F65CBDCE-EB8A-4AFB-B5A6-033192F13320.ttl
# F71686F1-516E-4E46-9E17-A208D95EE188.ttl
# F72B4607-B08D-4E2A-8EA3-F725F8E2F301.ttl
# F744F969-9F8E-476F-9391-959CAB237DE6.ttl
# F7824E06-B6EC-4794-8C70-33E9A9BFC07A.ttl
# F78BD8E4-8382-449B-84D3-F54C10A46DA5.ttl
# F86DFA63-5833-4BEE-BF92-0FC278980EAC.ttl
# F9124F8B-77C1-48CF-8189-1124F8236D24.ttl
# F9AD698A-C7D7-456E-AC36-5EABBA296CC3.ttl
# F9EA3ECF-141F-4790-9F19-FCFE102B1707.ttl
# FA15CBE2-6199-4E70-88F9-756CABFBB087.ttl
# FA3117BA-DCD5-4ACF-9065-E6C0A42AE0D9.ttl
# FA60690A-B840-4D32-9755-3763C0F9CFEA.ttl
# FA683F92-4E31-4545-822A-B721C6D095C5.ttl
# FAAD196F-5F70-4EC0-BC94-46E23D700C3C.ttl
# FAAEE841-373B-4919-93FB-1D9EFFF2BC08.ttl
# FABA22E7-32C8-4E1D-BF19-B5602E0A4A88.ttl
# FB1532B9-5848-43A8-B1F4-DCE0533FD9B5.ttl
# FB95E810-07FE-4C7B-BA7F-6C0AF77545CD.ttl
# FB9F249B-2BE5-4D45-938D-A274976BC899.ttl
# FBC2C941-8A5C-48F2-8CF7-ADC31A159F13.ttl
# FC03C6A2-71B0-4B9B-8A13-6602EA934CDF.ttl
# FC0B0190-6D0E-4B38-8DC1-2D0E2B603883.ttl
# FC0F1B02-89A8-4B5B-B964-3637D9E44945.ttl
# FC1E9293-B9C9-4A1A-9E8B-FCD1BC3E210D.ttl
# FC1F9C88-CE8A-4239-8499-BABA38377FE2.ttl
# FC4B8D6B-8CB8-454E-8188-903B7C264D86.ttl
# FC732EEE-5107-45FF-B7DA-5BA37D8AD692.ttl
# FC76E194-4113-45ED-8795-E5D8BAAAF632.ttl
# FD109A9D-BBCC-4D5D-874F-D3A57F4F9D65.ttl
# FD5603F4-9938-4849-A6B4-0A2E773236D8.ttl
# FD96033B-D987-4350-AA33-A3ACFB9E7535.ttl
# FDE2647E-336F-4D1F-AA85-FBC06CFEFF05.ttl
# FDE2F33A-2543-4BF3-AEF5-BF1B4851D0CC.ttl
# FEAF830F-397C-424D-ACF4-2F1F611C2559.ttl
# FEE32863-8C7A-467A-9012-63C02ADDAC53.ttl
# FFD06F38-493C-44CE-A4E4-E82D7FA2A36C.ttl

# %%
# !cat {path}/0006D323-D0B5-4E22-A26E-75ABB621F58E.ttl
# Out:
# @prefix parl: <http://data.parliament.uk/schema/parl#> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix sesame: <http://www.openrdf.org/schema/sesame#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix fn: <http://www.w3.org/2005/xpath-functions#> .
#
# <http://hansard.intranet.data.parliament.uk/Commons/2017-03-07/17030780000001> a parl:Proceeding ;
# 	dcterms:subject <http://data.parliament.uk/terms/91873> ;
# 	parl:text "
# Mr Philip Hollobone (in the Chair)
#
#
#
#  Share this contribution
#
#
# Would those who are not staying for the next debate please be kind enough to leave quickly and quietly? I see we have some of Liverpool’s finest in the Chamber.
#
#
#
#  Share this contribution  " ;
# 	dcterms:date "2017-03-07T00:00:00.000"^^xsd:dateTime ;
# 	dcterms:subject <http://data.parliament.uk/terms/11360> , <http://data.parliament.uk/terms/93057> .
