# %% [markdown]
# # Tinkering With with APPG Data

# %%
import sqlite3
import pandas as pd


# Available tables
'''
df_AGM
df_contacts
df_details
df_inKindBenefits
df_officers
df_regBenefits
'''

conn = sqlite3.connect('appg-data.db')
query = """SELECT * FROM df_inKindBenefits"""

df = pd.read_sql_query(query,conn)
df.head()
# Out:
#                   Source                                        Description  \
# 0               CalComms    Secretariat  From : 15/09/2020  To : 14/09/2021
# 1  Royal African Society    Secretariat  From : 08/01/2021  To : 07/01/2022
# 2          Chatham House    Secretariat  From : 29/01/2021  To : 28/01/2022
# 3               CalComms    Secretariat  From : 10/09/2020  To : 09/09/2021
# 4            Samir Takla  Samir Takla acts as the group's secretariat an...
#
#   Value £s  In bands of £1,500    Received  Registered  \
# 0                13,501-15,000  15/09/2020  17/09/2020
# 1                31,501-33,000  08/01/2021  21/04/2021
# 2                 9,001-10,500  29/01/2021  08/03/2021
# 3                13,501-15,000  10/09/2020  24/09/2020
# 4                  4,501-6,000  29/01/2021  15/02/2021
#
#                                               gid
# 0                                     afghanistan
# 1                                          africa
# 2                                          angola
# 3  canada-australia-new-zealand-and-the-uk-canzuk
# 4                                           egypt

# %% [markdown]
# ## Pattern Based Extraction
#
# If there are regular text patterns in a column, we can create a function parse that elements out of it. For example, if the secretariat is *always* described the same way, we can pull that out:

# %%
from parse import parse

fromto = lambda txt: parse('{thing}From : {from:tg}  To : {to:tg}', txt)

secretariat = fromto("Secretariat  From : 15/09/2020  To : 14/09/2021")
secretariat['thing'], secretariat['from'], secretariat['to']
# Out:
# ('Secretariat  ',
#  datetime.datetime(2020, 9, 15, 0, 0),
#  datetime.datetime(2021, 9, 14, 0, 0))

# %% [markdown]
# Apply the secretariat period extractor to each row, putting the results into the `from_to` column:

# %%
#parse('{}From : {from:tg} To : {to:tg}', "Secretariat From : 29/01/2021 To : 28/01/2022")
df['from_to'] = df["Description"].apply(fromto)

df.head()
# Out:
#                   Source                                        Description  \
# 0               CalComms    Secretariat  From : 15/09/2020  To : 14/09/2021
# 1  Royal African Society    Secretariat  From : 08/01/2021  To : 07/01/2022
# 2          Chatham House    Secretariat  From : 29/01/2021  To : 28/01/2022
# 3               CalComms    Secretariat  From : 10/09/2020  To : 09/09/2021
# 4            Samir Takla  Samir Takla acts as the group's secretariat an...
#
#   Value £s  In bands of £1,500    Received  Registered  \
# 0                13,501-15,000  15/09/2020  17/09/2020
# 1                31,501-33,000  08/01/2021  21/04/2021
# 2                 9,001-10,500  29/01/2021  08/03/2021
# 3                13,501-15,000  10/09/2020  24/09/2020
# 4                  4,501-6,000  29/01/2021  15/02/2021
#
#                                               gid  \
# 0                                     afghanistan
# 1                                          africa
# 2                                          angola
# 3  canada-australia-new-zealand-and-the-uk-canzuk
# 4                                           egypt
#
#                                              from_to
# 0  <Result () {'thing': 'Secretariat  ', 'from': ...
# 1  <Result () {'thing': 'Secretariat  ', 'from': ...
# 2  <Result () {'thing': 'Secretariat  ', 'from': ...
# 3  <Result () {'thing': 'Secretariat  ', 'from': ...
# 4  <Result () {'thing': "Samir Takla acts as the ...

# %% [markdown]
# We can perhaps more conveniently pull those elements into their own columns:

# %%
from pandas import Series

explode_from_to = lambda x: (x['from_to']['thing'], x['from_to']['from'], x['from_to']['to'])

df2 = pd.merge(df, df.dropna().apply(explode_from_to, axis=1).apply(Series), left_index=True, right_index=True)
df2.rename(columns={0:"thing", 1:"from", 2:"to"}, inplace=True)
df2.head()
# Out:
#                   Source                                        Description  \
# 0               CalComms    Secretariat  From : 15/09/2020  To : 14/09/2021
# 1  Royal African Society    Secretariat  From : 08/01/2021  To : 07/01/2022
# 2          Chatham House    Secretariat  From : 29/01/2021  To : 28/01/2022
# 3               CalComms    Secretariat  From : 10/09/2020  To : 09/09/2021
# 4            Samir Takla  Samir Takla acts as the group's secretariat an...
#
#   Value £s  In bands of £1,500    Received  Registered  \
# 0                13,501-15,000  15/09/2020  17/09/2020
# 1                31,501-33,000  08/01/2021  21/04/2021
# 2                 9,001-10,500  29/01/2021  08/03/2021
# 3                13,501-15,000  10/09/2020  24/09/2020
# 4                  4,501-6,000  29/01/2021  15/02/2021
#
#                                               gid  \
# 0                                     afghanistan
# 1                                          africa
# 2                                          angola
# 3  canada-australia-new-zealand-and-the-uk-canzuk
# 4                                           egypt
#
#                                              from_to  \
# 0  <Result () {'thing': 'Secretariat  ', 'from': ...
# 1  <Result () {'thing': 'Secretariat  ', 'from': ...
# 2  <Result () {'thing': 'Secretariat  ', 'from': ...
# 3  <Result () {'thing': 'Secretariat  ', 'from': ...
# 4  <Result () {'thing': "Samir Takla acts as the ...
#
#                                                thing       from         to
# 0                                      Secretariat   2020-09-15 2021-09-14
# 1                                      Secretariat   2021-01-08 2022-01-07
# 2                                      Secretariat   2021-01-29 2022-01-28
# 3                                      Secretariat   2020-09-10 2021-09-09
# 4  Samir Takla acts as the group's secretariat an... 2021-01-29 2022-01-28

# %% [markdown]
# ## Entity Extraction
#
# We can trivially extract entities from a text field using the `spacy` package:

# %%
#%pip install --upgrade spacy
import spacy
nlp = spacy.load("en_core_web_sm")
# Out:
# /usr/local/lib/python3.9/site-packages/spacy/util.py:833: UserWarning: [W095] Model 'en_core_web_sm' (3.0.0) was trained with spaCy v3.0 and may not be 100% compatible with the current version (3.2.0). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %% [markdown]
# For example, extract entities in the *Description* column:

# %%
get_entities = lambda desc: [f"{entity.label_} :: {entity.text}" for entity in nlp(desc).ents]

df['entities'] = df["Description"].apply(get_entities)
df.head()
# Out:
#                   Source                                        Description  \
# 0               CalComms    Secretariat  From : 15/09/2020  To : 14/09/2021
# 1  Royal African Society    Secretariat  From : 08/01/2021  To : 07/01/2022
# 2          Chatham House    Secretariat  From : 29/01/2021  To : 28/01/2022
# 3               CalComms    Secretariat  From : 10/09/2020  To : 09/09/2021
# 4            Samir Takla  Samir Takla acts as the group's secretariat an...
#
#   Value £s  In bands of £1,500    Received  Registered  \
# 0                13,501-15,000  15/09/2020  17/09/2020
# 1                31,501-33,000  08/01/2021  21/04/2021
# 2                 9,001-10,500  29/01/2021  08/03/2021
# 3                13,501-15,000  10/09/2020  24/09/2020
# 4                  4,501-6,000  29/01/2021  15/02/2021
#
#                                               gid  \
# 0                                     afghanistan
# 1                                          africa
# 2                                          angola
# 3  canada-australia-new-zealand-and-the-uk-canzuk
# 4                                           egypt
#
#                                              from_to  \
# 0  <Result () {'thing': 'Secretariat  ', 'from': ...
# 1  <Result () {'thing': 'Secretariat  ', 'from': ...
# 2  <Result () {'thing': 'Secretariat  ', 'from': ...
# 3  <Result () {'thing': 'Secretariat  ', 'from': ...
# 4  <Result () {'thing': "Samir Takla acts as the ...
#
#                                             entities
# 0  [ORG :: Secretariat, DATE :: 15/09/2020, DATE ...
# 1                               [ORG :: Secretariat]
# 2  [ORG :: Secretariat, DATE :: 29/01/2021, DATE ...
# 3           [ORG :: Secretariat, DATE :: 10/09/2020]
# 4  [PERSON :: Samir Takla, PERSON :: Carole Cosgr...

# %% [markdown]
# We can explode these out into a long format dataframe:

# %%
df_long = df.explode('entities')
df_long.rename(columns={"entities":"entity"}, inplace=True)
df_long.head()
# Out:
#                   Source                                      Description  \
# 0               CalComms  Secretariat  From : 15/09/2020  To : 14/09/2021
# 0               CalComms  Secretariat  From : 15/09/2020  To : 14/09/2021
# 0               CalComms  Secretariat  From : 15/09/2020  To : 14/09/2021
# 1  Royal African Society  Secretariat  From : 08/01/2021  To : 07/01/2022
# 2          Chatham House  Secretariat  From : 29/01/2021  To : 28/01/2022
#
#   Value £s  In bands of £1,500    Received  Registered          gid  \
# 0                13,501-15,000  15/09/2020  17/09/2020  afghanistan
# 0                13,501-15,000  15/09/2020  17/09/2020  afghanistan
# 0                13,501-15,000  15/09/2020  17/09/2020  afghanistan
# 1                31,501-33,000  08/01/2021  21/04/2021       africa
# 2                 9,001-10,500  29/01/2021  08/03/2021       angola
#
#                                              from_to              entity
# 0  <Result () {'thing': 'Secretariat  ', 'from': ...  ORG :: Secretariat
# 0  <Result () {'thing': 'Secretariat  ', 'from': ...  DATE :: 15/09/2020
# 0  <Result () {'thing': 'Secretariat  ', 'from': ...  DATE :: 14/09/2021
# 1  <Result () {'thing': 'Secretariat  ', 'from': ...  ORG :: Secretariat
# 2  <Result () {'thing': 'Secretariat  ', 'from': ...  ORG :: Secretariat

# %% [markdown]
# And maybe make them easier to search on by type?

# %%
df_long[["entity_typ", "entity_value"]] = df_long["entity"].str.split(" :: ").apply(Series)
df_long.head()
# Out:
#                   Source                                      Description  \
# 0               CalComms  Secretariat  From : 15/09/2020  To : 14/09/2021
# 0               CalComms  Secretariat  From : 15/09/2020  To : 14/09/2021
# 0               CalComms  Secretariat  From : 15/09/2020  To : 14/09/2021
# 1  Royal African Society  Secretariat  From : 08/01/2021  To : 07/01/2022
# 2          Chatham House  Secretariat  From : 29/01/2021  To : 28/01/2022
#
#   Value £s  In bands of £1,500    Received  Registered          gid  \
# 0                13,501-15,000  15/09/2020  17/09/2020  afghanistan
# 0                13,501-15,000  15/09/2020  17/09/2020  afghanistan
# 0                13,501-15,000  15/09/2020  17/09/2020  afghanistan
# 1                31,501-33,000  08/01/2021  21/04/2021       africa
# 2                 9,001-10,500  29/01/2021  08/03/2021       angola
#
#                                              from_to              entity  \
# 0  <Result () {'thing': 'Secretariat  ', 'from': ...  ORG :: Secretariat
# 0  <Result () {'thing': 'Secretariat  ', 'from': ...  DATE :: 15/09/2020
# 0  <Result () {'thing': 'Secretariat  ', 'from': ...  DATE :: 14/09/2021
# 1  <Result () {'thing': 'Secretariat  ', 'from': ...  ORG :: Secretariat
# 2  <Result () {'thing': 'Secretariat  ', 'from': ...  ORG :: Secretariat
#
#   entity_typ entity_value
# 0        ORG  Secretariat
# 0       DATE   15/09/2020
# 0       DATE   14/09/2021
# 1        ORG  Secretariat
# 2        ORG  Secretariat

# %% [markdown]
# What types of entity are there?

# %%
df_long['entity_typ'].value_counts()

# GPE - geo-political entity
# Out:
# ORG            579
# DATE           428
# PERSON          82
# GPE             51
# CARDINAL        27
# NORP            26
# FAC              4
# EVENT            2
# LOC              2
# WORK_OF_ART      1
# PRODUCT          1
# Name: entity_typ, dtype: int64

# %%
df_long[df_long['entity_typ']=='ORG']["entity_value"].value_counts()
# Out:
# Secretariat               231
# APPG                        6
# Healthcomms Consulting      5
# College Green Group         4
# DevoConnect                 4
#                          ...
# KPMG UK                     1
# The Gym Group               1
# EDF Energy                  1
# EELGA                       1
# Access Industry Forum       1
# Name: entity_value, Length: 310, dtype: int64

# %% [markdown]
# ## Extract Value Range
#
# The value range would be more useful if it were split into "lower_value" and "upper_value" bands:

# %%
df[["lower_bound", "upper_bound"]] = df["Value £s  In bands of £1,500"].str.split("-").apply(Series)

df
# Out:
#                                     Source  \
# 0                                 CalComms
# 1                    Royal African Society
# 2                            Chatham House
# 3                                 CalComms
# 4                              Samir Takla
# ..                                     ...
# 382  Association for Young People's Health
# 383                   InterClimate Network
# 384                  British Youth Council
# 385                 YMCA England and Wales
# 386                    Youth Employment UK
#
#                                            Description  \
# 0      Secretariat  From : 15/09/2020  To : 14/09/2021
# 1      Secretariat  From : 08/01/2021  To : 07/01/2022
# 2      Secretariat  From : 29/01/2021  To : 28/01/2022
# 3      Secretariat  From : 10/09/2020  To : 09/09/2021
# 4    Samir Takla acts as the group's secretariat an...
# ..                                                 ...
# 382    Secretariat  From : 04/02/2021  To : 03/02/2022
# 383    Secretariat  From : 15/01/2021  To : 14/01/2022
# 384  Joint Secretariat  From : 29/01/2021  To : 28/...
# 385  Joint Secretariat  From : 29/01/2021  To : 28/...
# 386    Secretariat  From : 17/06/2021  To : 16/06/2022
#
#     Value £s  In bands of £1,500    Received  Registered  \
# 0                  13,501-15,000  15/09/2020  17/09/2020
# 1                  31,501-33,000  08/01/2021  21/04/2021
# 2                   9,001-10,500  29/01/2021  08/03/2021
# 3                  13,501-15,000  10/09/2020  24/09/2020
# 4                    4,501-6,000  29/01/2021  15/02/2021
# ..                           ...         ...         ...
# 382                  4,501-6,000  04/02/2021  07/06/2021
# 383                  6,001-7,500  15/01/2021  07/07/2021
# 384                  1,501-3,000  29/01/2021  01/06/2021
# 385                  1,501-3,000  29/01/2021  01/06/2021
# 386                  6,001-7,500  17/06/2021  04/08/2021
#
#                                                 gid lower_bound upper_bound
# 0                                       afghanistan      13,501      15,000
# 1                                            africa      31,501      33,000
# 2                                            angola       9,001      10,500
# 3    canada-australia-new-zealand-and-the-uk-canzuk      13,501      15,000
# 4                                             egypt       4,501       6,000
# ..                                              ...         ...         ...
# 382                            young-peoples-health       4,501       6,000
# 383             youth-action-against-climate-change       6,001       7,500
# 384                                   youth-affairs       1,501       3,000
# 385                                   youth-affairs       1,501       3,000
# 386                                youth-employment       6,001       7,500
#
# [387 rows x 8 columns]
